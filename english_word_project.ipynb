# %%
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import stopwords
import re 

from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

import time as time
import csv

# %%
tech_it_words = ['effective', 'typing', 'rapid', 'object', 'powerful', 'syntax',  'simple', 'together', 
                 'ideal', 'dynamic', 'elegant', 'approach', 'level', 'nature', 'learn', 'areas',
                 'language', 'programs', 'python', 'source', 'contains', 'party', 'available', 'freely', 'pointers', 'tools', 'https', 'org',  'web', 'modules', 'major',
                 'tutorial', 'hands', 'informally', 'handy', 'helps', 'concepts', 'introduces', 'basic', 'features', 'reader', 'self', 'examples', 'system', 'line', 'well', 
                 'read', 'style', 'used', 'various', 'idea', 'covering', 'flavor', 'ready', 'write', 'every', 'several', 'Standard', 
                 'give', 'feature', 'Instead', 'Library', 'cover', 'library', 'depth', 'attempt', 
                 'single', 'able', 'described', 'books', 'commonly', 'reading'  , 'allows', 'throw', 'small', 'design', 'interpreter', 'interface', 
                 'computers', 'collection', 'maybe', 'database', 'offers', 'interpreted', 'split', 'writing', 'Whetting', 'program', 'batch', 'tasks',
                 'scripts', 'general', 'Some', 'experiment', 'moving', 'On', 'task', 'problem', 'work', 'job', 'applications', 'libraries', 'extension',
                 'sockets', 'games', 'implement', 'graphical', 'slow', 'around', 'written', 'away', 'dictionaries', 'things', 'lot', 'macOS', 
                 'interactively', 'systems', 'applicable', 'search', 'Tk', 'wish', 'developer', 'Or', 'testing', 'Awk', 'automate', 'Your',
                 'suited', 'compactly', 'code', 'operating', 'custom', 'Perhaps', 'real', 'tedious', 'desk', 'cycle', 'first', 
                 'functions', 'least', 'reused', 'error', 'learning', 'linking', 'checking', 'game', 'hand', 'software', 'Appetite', 'Java', 
                 'bunch', 'domain', 'programming', 'typically', 'readably', 'offering', 'necessary', 'complicated', 'simpler', 'flexible', 
                 'shell', 'done', 'compile', 'reasons', 'suite', 'standard', 'equivalent', 'calculator', 'whole', 'rename', 'Unix', 'Perl', 
                 'structure', 'larger', 'start', 'photo', 'user', 'specialized', 'GUI', 'Because', 'O', 'number', 'arrays', 'interfaces', 
                 'professional', 'Windows', 'Programs', 'types',  'files', 'shorter', 'offer', 'could', 'test', 'get', 
                 'toolkits', 'replace', 'calls', 'built', 'find', 'development', 'file', 'much', 
                 'text',   'bottom', 'script', 'support', 'changing']

# %%
# 이미 알고있는단어도 제외시킨다. 
study_word = ['anything', 'outside', 'uncertainty', 'companies', 'using', 'ASCII', 'users', 'de', 'bytes', 
              'There', 'investors', 'positions', 'deplatform', 'positively', 'make', 'going', 'note', 
              'jointly', 'refer', 'works', 'bit', 'taxes', 'languages', 'Business', 'allocation', 'For', 
              'buy', 'brokerage', 'Only', 'plus', 'fund', 'cryptocurrency', 'In', 'creates', 'loss', 'many',
              'change', 'sounds', 'ban', 'references', 'use', 'appreciated', 'Back', 'block', 'easy', 
              'Ford', 'face', 'open', 'experience', 'lemonade', 'function', 'less', 'Twitter', 'account',
              'reverse', 'capital', 'appeals', 'rates', 'Python', 'Communications', 'social', 'CPA', 
              'within', 'day', 'Better', 'working', 'remove', 'blocked', 'got', 'public', 'negative',
              'provide', 'lobbying', 'court', 'applied', 'avoid', 'strict', 'clear', 'never', 'courts',
              'welcome', 'gives', 'As', 'Sure', 'included', 'platform', 'best', 'Erdogan', 'markets', 
              'IBM', 'ID', 'current', 'joining', 'taking', 'financial', 'carry', 'security', 'You', 
              'rights', 'emergency', 'platforms', 'serves', 'representing', 'yet', 'years', 'pleased',
              'paper', 'know', 'We', 'Carolina', 'something', 'Mike', 'buying', 'also', 'prepared', 
              'heard', 'Also', 'offset', 'deny', 'North', 'save', 'Powers', 'even', 'needs', 
              'membership', 'decision', 'ways', 'high', 'rising', 'person', 'interest', 'term', 
              'Supreme', 'Selling', 'Texas', 'CFP', 'Industry', 'like', 'media', 'beneficial', 'And', 
              'answer', 'easily', 'accounts', 'IRS', 'digits', 'different', 'names', 'protected', 
              'counties', 'Harvesting', 'comes', 'is', 'i', 'publish', 'married', 'deSteiger', 'last', 
              'example', 'free', 'and', 'yesterday', 'decide', 'filing', 'long', 'stock', 'raised', 
              'property', 'Dan', 'When', 'tax', 'ago', 'paid', 'across', 'stocks', 'HB', 'way', 'called', 
              'expense', 'k', 'groups', 'as', 'good', 'More', 'Tobias', 'classifies', 'realized', 
              'decisions', 'receiving', 'bill', 'SEC', 'CNN', 'either', 'bought', 'run', 'one', 'with', 
              'holdings', 'ETF', 'asset', 'planner', 'online', 'right', 'want', 'similar', 'important', 
              'Russ', 'soon', 'better', 'type', 'businesses', 'US', 'cut', 'may', 'investing', 'thrown',
              'I', 'thanked', 'mutual', 'seeking', 'disallow', 'lower', 'investments', 'Indiana', 'days', 
              'looking', 'immediately', 'lawmakers', 'step', 'Turkey', 'asking', 'portion', 'Justice', 
              'gain', 'rules', 'Yes', 'President', 'illegal', 'Friday', 'whose', 'think', 'rebalance', 
              'equal', 'NetChoice', 'Marchese', 'turned', 'shared', 'Wednesday', 'portfolio', 'hold', 
              'crypto', 'period', 'perhaps', 'opportunity', 'financially', 'two', 'Making', 'said', 
              'name', 'content', 'understand', 'speech', 'trading', 'careful', 'limit', 'cost', 'future',
              'forward', 'time', 'investment', 'problems', 'Court', 'result', 'ordinary', 'regular', 'So',
              'let', 'however', 'people', 'law', 'cryptocurrencies', 'back', 'benefits', 'filed', 
              'harvesting', 'need', 'Chris', 'specifically', 'Facebook', 'makes', 'provision', 'directly',
              'based', 'rest', 'Computer', 'expressions', 'miss', 'effect', 'depending', 'take', 
              'reference', 'lost', 'words', 'thanks', 'data', 'NATO', 'large', 'wash', 'contain', 'stay', 
              'sale', 'short', 'monthly', 'subject', 'money', 'regulate', 'Michigan', 'us', 'Ashlee', 
              'quickly', 'losses', 'an', 'What', 'expression', 'holding', 'harvest', 'apply', 'book',
              'market', 'IRAs', 'expects', 'rate', 'taxable', 'full', 'After', 'gains', 'income', 'date', 
              'longer', 'If', 'year', 'apple', 'applies', 'terrorist', 'sell', 'Build', 'YouTube', 'big', 
              'advantage', 'access', 'adviser', 'letters', 'new', 'lets', 'Samuel', 'higher', 'Two', 
              'remaining', 'housing', 'rule', 'Alito', 'But', 'advantaged', 'would', 'booked', 'class',
              'vehicles', 'tech', 'numerical', 'side', 'bond', 'demonetize', 'say', 'How', 'IRA', 'appeal',
              'unrealized', 'help', 'group', 'benefit', 'million', 'Virginia', 'company', 'application', 
              'state', 'That', 'hopeful' , 'third' , 'This' , 'Or' , 'TWTR' , 'Joe Biden']

# %%
## stop_words 불용어
stop_words_re = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 
                 "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 
                 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 
                 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 
                 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 
                 "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 
                 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 
                 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 
                 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 
                 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 
                 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 
                 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 
                 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 
                 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 
                 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn',
                 "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 
                 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn',
                 "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 
                 'The', 'C' , 'it' ,'IT' ,'It' ,'www', 'site' ,'Masnick' ,'Techdirt' , 'Zanolli' ,'pytube' ,'Pytube'] + study_word + tech_it_words

# %%
text01 = str(input('영어문장 입력하세요 :  '))
# Out:
# 영어문장 입력하세요 :  When instantiating a YouTube object, these named arguments can be passed in to improve functionality.  The on_progress_callback function will run whenever a chunk is downloaded from a video, and is called with three arguments: the stream, the data chunk, and the bytes remaining in the video. This could be used, for example, to display a progress bar.  The on_complete_callback function will run after a video has been fully downloaded, and is called with two arguments: the stream and the file path. This could be used, for example, to perform post-download processing on a video like trimming the length of it.  The use_oauth and allow_oauth_cache flags allow you to authorize pytube to interact with YouTube using your account, and can be used to bypass age restrictions or access private videos and playlists. If allow_oauth_cache is set to True, you should only be prompted to do so once, after which point pytube will cache the tokens it needs to act on your behalf. Otherwise,
# ...

# %%
# 전처리 영어만 제외하고 모두 날리기 
text01 = re.sub('[^a-zA-Z]' ,' ',text01)

# %%
token_words = word_tokenize(text01)

# %%
# 불용어 + 학습단어가 있으면 제외하고 단어 출력 
text_word = [word for word in token_words if not word in stop_words_re]     
# 중복제거 
text_word = list(set(text_word))
print(text_word)
# Out:
# ['improve', 'post', 'downloaded', 'named', 'Otherwise', 'cache', 'next', 'section', 'chunk', 'allow', 'oauth', 'age', 'functionality', 'stream', 'video', 'download', 'interact', 'three', 'callback', 'path', 'private', 'prompted', 'videos', 'playlists', 'act', 'streams', 'behalf', 'length', 'tokens', 'arguments', 'bar', 'perform', 'Once', 'fully', 'action', 'instantiating', 'set', 'point', 'processing', 'authorize', 'complete', 'progress', 'whenever', 'True', 'bypass', 'discussed', 'display', 'trimming', 'requires', 'authenticated', 'restrictions', 'passed', 'flags']

# %%
# 모르는 단어 검색 


path = 'C:/Users/crid2/driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# 옵션 생성
options = webdriver.ChromeOptions()
# 창 숨기는 옵션 추가
options.add_argument("headless")

# 암묵적 대기 브라우저에서 사용되는 엔진 자체에서 파싱되는 시간을 기다림 
# 모든요소에 다적용 
# 슬립보다 낭비되는시간이 적음 
# driver.implicitly_wait()



driver.get('https://en.dict.naver.com/#/main')
driver.implicitly_wait(30)


mean_words = [] 



for word in text_word :
        
    search_input = driver.find_element(By.XPATH, '//*[@id="ac_input"]')
    search_input.send_keys(word)
    search_input.send_keys(Keys.RETURN)


    ### 현재 url 다시 드라이브에 get 해서 다음으로 넘어갈수있게 함

    driver.get(driver.current_url)
    search_output = driver.find_element(By.XPATH, '//*[@id="searchPage_entry"]/div/div[1]')
    mean_words.append(search_output.text)
    mean_words.append('='* 100)


    print(search_output.text)
    print('='* 100)
    print()

    # 그다음 url 가져오고 다시 돌아가기
    driver.get('https://en.dict.naver.com/#/main')

driver.quit()
# Out:
# C:\Users\crid2\AppData\Local\Temp\ipykernel_15344\936234179.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# improve
# 오스포드 중요어휘
# 어휘등급
# 동사 개선되다, 나아지다; 개선하다, 향상시키다
# 미국∙영국 [ ɪmˈpruːv ]
# 미국식 [ ɪmˈpruːv ]
# All
# 23
# 옥스퍼드 영한사전
# ...
#
# post
# 오스포드 중요어휘
# 어휘등급
# 1.
# 명사 英 우편
# 2.
# 명사 英 우편물
# 3.
# 동사 英 (우편물을) 발송[우송]하다 (→mail)
# 4.
# 동사 英 (편지 등을) 우체통에 넣다[부치다]
# 6
# 미국식 [ poʊst ]
# 영국식 [ pəʊst ]
# All
# 4
# 옥스퍼드 영한사전
# ...
#
# download
# ( 과거형: downloaded ) ( 과거 분사: downloaded )
# 1.
# 동사 컴퓨터 (데이터를) 다운로드하다[내려받다] (→load), (↔upload)
# 2.
# 명사 컴퓨터 다운로드한 데이터
# All
# 3
# 옥스퍼드 영한사전
# ...
#
# named
# 형용사 지명된, 지정의; 유명한
# 미국∙영국 [ néimd ]
# All
# 동아출판 프라임 영한사전
# ...
#
# otherwise
# 오스포드 중요어휘
# 어휘등급
# 1.
# 부사 (만약) 그렇지 않으면[않았다면]
# 2.
# 부사 그 외에는
# 3.
# 부사 (…와는) 다르게[다른 방법으로], 달리
# 미국식 [ ˈʌðərwaɪz ]
# 영국식 [ ˈʌðəwaɪz ]
# All
# 22
# 옥스퍼드 영한사전
# ...
#
# cache
# 1.
# 명사 (무기 등의) 은닉처
# 2.
# 명사 컴퓨터 캐시(고속 기억 장치)
# 3.
# 동사 은닉하다
# 4.
# 동사 컴퓨터 캐시에 저장하다
# ...

# %%
# 공부단어 txt 반환 
with open('study_word.txt' , 'w' , encoding='utf-8') as f : 
     f.writelines('\n'.join(mean_words))

# %%
with open('search_words.txt' , 'w' , encoding='utf-8') as f : 
     f.writelines('\n'.join(text_word))
