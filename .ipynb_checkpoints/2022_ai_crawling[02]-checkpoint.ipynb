# %%
import numpy  as np
import pandas as pd

# 시각화
import matplotlib.pyplot as plt 
# %matplotlib inline

import seaborn as sns

import json 

import warnings
warnings.filterwarnings(action='ignore')

from datetime import date, datetime, timedelta
from dateutil.parser import parse


# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 


# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False


# crawling
from bs4 import BeautifulSoup
from urllib.request import urlopen , urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

import requests 
import re

print('numpy version  - ' , np.__version__)
print('pandas version - ' , pd.__version__)
# Out:
# numpy version  -  1.20.3
# pandas version -  1.3.4

# %% [markdown]
# - 영화평점 스크래핑 & 시각화
# - https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20220407

# %%
try :
    html = urlopen('https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20220407')
    # print(html.read())
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')
    print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&amp;date=20220407" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# <meta content="네이버 영화" property="og:article:author"/>
# <meta content="https://movie.naver.com/" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>랭킹 : 네이버 영화</title>
# <link href="/common/css/movie_tablet.css?20220406163047" rel="stylesheet" type="text/css"/>
# <link href="/common/css/common.css?20220406163047" rel="stylesheet" type="text/css"/>
# <link href="/common/css/layout.css?20220406163047" rel="stylesheet" type="text/css"/>
# <link href="/common/css/old_default.css?20220406163047" rel="stylesheet" type="text/css"/>
# <link href="/common/css/old_layout.css?20220406163047" rel="stylesheet" type="text/css"/>
# <link href="/common/css/old_common.css?20220406163047" rel="stylesheet" type="text/css"/>
# <link href="/common/css/old_super_db.css?20220406163047" rel="stylesheet" type="text/css"/>
# <script src="/common/js/default-min.js" type="text/javascript"></script>
# </meta></meta></head>
# <body>
# <div class="fix" id="wrap">
# <!-- GNB -->
# <script type="text/javascript">
# function delayed_submit(object) {
# 	if (navigator.userAgent.indexOf('MSIE') == -1) {
# 		var b = c = new Date();
#       	while ((b.getTime() - c.getTime()) < 100) {
# 			b = new Date();
#       	}
# 		//window.setTimeout(function() {object.submit(); console.log('s');}, 300);
# 	}
# }
# var gnb_service = 'movie';
# var gnb_logout = 'http://movie.naver.com/movie/sdb/rank/rmovie.naver%3Fsel%3Dcur%26date%3D20220407';
# var gnb_template = "gnb_utf8"; /* https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn */
# var gnb_brightness=3;
# var gnb_response = true;
# </script>
# <a name="gnb_top"></a>
# <!-- skip navigation -->
# <div id="u_skip">
# <a href="#header" onclick="document.getElementById('header').tabIndex=-1;document.getElementById('header').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" id="gnb_goContent" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <!-- //skip navigation -->
# <!-- GNB -->
# <div class="gnb_container">
# <div class="gnb_content">
# <div class="gnb_box">
# <div class="gnb_wrap">
# <div id="gnb" onload="javascript:getGNB();">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn" type="text/javascript"></script>
# </div>
# </div>
# <!-- 검색창 -->
# <form action="/movie/search/result.naver" id="jSearchForm" method="get" style="margin:0;display:none;">
# <input maxlength="100" name="query" title="영화검색" type="text"/>
# <input name="section" type="hidden" value="all"/>
# </form>
# <fieldset class="srch_area" id="jSearchArea">
# <legend><span class="blind">영화검색 영역</span></legend>
# <div class="srch_field_on _view">
# <span class="ipt_srch">
# <label for="ipt_tx_srch" id="search_placeholder">영화검색</label>
# <input accesskey="s" autocomplete="off" class="ipt_tx_srch" id="ipt_tx_srch" maxlength="100" name="query" style="ime-mode:active;" type="text"/>
# <span class="align"></span>
# <span class="auto_tx"><a href="#" title="자동완성 펼치기"><img alt="자동완성 펼치기" height="4" src="https://ssl.pstatic.net/static/movie/2012/06/srch_arrow_down.gif" title="자동완성 펼치기" width="7"/></a></span>
# </span>
# <button class="btn_srch" onclick="clickcr(this, 'GNB.search', '', '', event); delayed_submit(this);" title="검색" type="submit"><span class="blind">검색</span></button>
# <!-- 자동 완성 영역임 #autocomplate_template-->
# </div>
# </fieldset>
# <!-- //검색창 -->
# </div>
# </div>
# </div>
# <!-- //GNB -->
# <!-- nClicks -->
# <script type="text/javascript">var nsc = "movie.sdb";</script>
# <script src="/common/js/clickcr.js" type="text/javascript"></script>
# <!-- // nClicks -->
# <!-- //GNB -->
# <!-- LNB -->
# <!-- header -->
# <div id="header">
# <h1 class="svc_name">
# <a class="ci_logo" href="http://www.naver.com/" id="lnb_gonaver" onclick="clickcr(this, 'LNB.naver', '', '', event);" title="naver로 바로가기"><img alt="NAVER" height="13" src="https://ssl.pstatic.net/static/movie/2013/07/logo_ci.png" width="62"/></a>
# <a class="svc_logo" href="/" onclick="clickcr(this, 'LNB.movie', '', '', event);" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="https://ssl.pstatic.net/static/movie/2012/06/logo_svc.png" width="34"/></a>
# </h1>
# <div class="scrollbar scrollbar-noscript" id="scrollbar">
# <div class="scrollbar-box">
# <div class="scrollbar-content">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <a class="menu01" href="/" onclick="clickcr(this, 'LNB.home', '', '', event);" title="영화홈"><strong>영화홈</strong></a>
# </li>
# <li>
# <a class="menu02" href="/movie/running/current.naver" onclick="clickcr(this, 'LNB.movies', '', '', event);" title="상영작·예정작"><strong>상영작·예정작</strong></a>
# <ul class="navi_sub" style="display:none">
# <li><a class="sub2_1" href="/movie/running/current.naver" onclick="clickcr(this, 'LNB.now', '', '', event);" title="현재 상영영화"><em>현재 상영영화</em></a></li>
# <li><a class="sub2_2" href="/movie/running/premovie.naver" onclick="clickcr(this, 'LNB.soon', '', '', event);" title="개봉 예정영화"><em>개봉 예정영화</em></a></li>
# <li><a class="sub2_4" href="/movie/running/movieclip.naver" onclick="clickcr(this, 'LNB.tailer', '', '', event);" title="예고편"><em>예고편</em></a></li>
# </ul>
# </li>
# <li>
# <a class="menu03_on" href="/movie/sdb/rank/rmovie.naver" onclick="clickcr(this, 'LNB.db', '', '', event);" title="영화랭킹"><strong>영화랭킹</strong></a>
# <ul class="navi_sub" style="display:block">
# <li><a class="sub3_1_on" href="/movie/sdb/rank/rmovie.naver" onclick="clickcr(this, 'LNB.rank', '', '', event);" title="랭킹"><em>랭킹</em></a></li>
# <li><a class="sub3_2" href="/movie/sdb/browsing/bmovie_nation.naver" onclick="clickcr(this, 'LNB.dir', '', '', event);" title="디렉토리"><em>디렉토리</em></a></li>
# </ul>
# </li>
# <li>
# <a class="menu07" href="/movie/point/af/list.naver" onclick="clickcr(this, 'LNB.comm', '', '', event);" title="평점"><strong>평점</strong></a>
# <ul class="navi_sub" style="display:none">
# <li><a class="sub7_1" href="/movie/point/af/list.naver" onclick="clickcr(this, 'LNB.rating', '', '', event);" title="네티즌 평점"><em>네티즌 평점</em></a></li>
# <li><a class="sub7_2" href="/movie/board/review/list.naver" onclick="clickcr(this, 'LNB.review', '', '', event);" title="네티즌 리뷰"><em>네티즌 리뷰</em></a></li>
# </ul>
# </li>
# <li>
# <a class="menu08" href="http://serieson.naver.com/movie/home.nhn" onclick="clickcr(this, 'LNB.download', '', '', event);" target="_blank" title="다운로드"><strong>다운로드</strong></a>
# </li>
# <li class="nav_indi">
# <a href="http://tv.naver.com/indiecinema" target="_blank" title="인디극장 UP"><strong>인디극장 UP</strong></a><!-- N=a:LNB.indie -->
# </li>
# </ul>
# <!-- div class="view_mode">
# 							<a href="#" title="" class="normal_on"><em>1단 보기</em></a>
# 							<a href="#" title="" class="wide_off"><em>2단 보기</em></a>
# 						</div -->
# </div>
# </div>
# </div>
# <div class="scrollbar-v">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <!-- //header -->
# <!-- //LNB -->
# <div id="container">
# <!-- content -->
# <div id="content">
# <div class="article">
# <div class="old_layout old_super_db">
# <h3 class="h_db_rank"><strong class="blind">랭킹</strong></h3>
# <ul class="tab_db_rank">
# <li><a class="db_tab01_on" href="/movie/sdb/rank/rmovie.naver" title="영화"><em>영화</em></a></li>
# <li><a class="db_tab02" href="/movie/sdb/rank/rpeople.naver" title="영화인"><em>영화인</em></a></li>
# <!-- li><a href="/movie/sdb/rank/rfestival.naver" title="영화제" class="db_tab03"><em>영화제</em></a></li -->
# <!-- li><a href="/movie/sdb/rank/rcompany.naver" title="영화사" class="db_tab04"><em>영화사</em></a></li -->
# <!-- li><a href="/movie/sdb/rank/rnews.naver" title="기자영화" class="db_tab05"><em>기자</em></a></li -->
# <!-- li><a href="/movie/sdb/rank/rreview.naver" title="네티즌리뷰" class="db_tab06"><em>네티즌리뷰</em></a></li -->
# </ul>
# <!-- Content Body -->
# <div class="type_1" id="cbody">
# <div id="old_content">
# <h4 class="tlt"><img alt="영화랭킹" height="15" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/tlt_ranking_movie.gif" width="65"/>
# </h4>
# <!-- 탭메뉴 -->
# <div class="tab_type_6">
# <ul><!--활성화된 탭의 이미지는 _on.gif 입니다-->
# <li><a href="rmovie.naver?sel=cnt&amp;date=20220407"><img alt="조회순" height="28" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/tab_movie_1_off.gif" width="112"/></a></li>
# <li><a href="rmovie.naver?sel=cur&amp;date=20220407"><img alt="평점순(현재상영영화)" height="28" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/tab_movie_2_on.gif" width="126"/></a></li>
# <li><a href="rmovie.naver?sel=pnt&amp;date=20220407"><img alt="평점순(모든영화)" height="28" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/tab_movie_3_off.gif" width="126"/></a></li>
# </ul>
# <p class="r_date">2022.04.07 <a href="rmovie.naver?sel=cur&amp;tg=0&amp;date=20220406"><img alt="prev" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/btn_prev.gif" style="margin-right:1px;" width="13"/></a><a href="rmovie.naver?sel=cur&amp;tg=0&amp;date=20220408"><img alt="next" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/btn_next.gif" width="13"/></a></p>
# </div>
# <!-- //탭메뉴 -->
# <!-- 랭킹 리스트 -->
# <table cellspacing="0" class="list_ranking">
# <caption class="blind">랭킹 테이블</caption>
# <col width="6%"/><col width="*"/><col width="15%"/><col width="3%"/><col width="12%"/><col width="2%"/><col width="5%"/>
# <thead>
# <tr>
# <th scope="col">순위</th>
# <th scope="col">영화명</th>
# <th colspan="3" scope="col">평점</th>
# <th colspan="2" scope="col">변동폭</th>
# </tr>
# </thead>
# <tbody>
# <tr><td class="blank01" colspan="8"></td></tr>
# <!-- 예제
# 				<tr>
# 					<td class="ac"><img src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g50.gif" alt="50" width="14" height="13"></td>
# 					<td class="title"><a href="#">트랜스포머</a></td>
# 					<td class="ac"><img src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" alt="down" width="7" height="10"></td>
# 					<td class="range ac">7</td>
# 				</tr>
# 				-->
# <tr>
# <td class="ac"><img alt="01" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r01.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=187320" title="씽2게더">씽2게더</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:93.99999618530273%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">9.40</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=187320">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="02" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r02.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=14448" title="패왕별희 디 오리지널">패왕별희 디 오리지널</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:93.10000419616699%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">9.31</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=14448">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="03" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r03.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=213733" title="극장판 주술회전 0">극장판 주술회전 0</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:92.60000228881836%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">9.26</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=213733">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="04" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r04.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=19335" title="해피 투게더">해피 투게더</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:91.80000305175781%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">9.18</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=19335">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="05" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r05.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=201073" title="코다">코다</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:91.49999618530273%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">9.15</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=201073">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="06" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r06.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=38546" title="아무도 모른다">아무도 모른다</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:88.69999885559082%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.87</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=38546">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="07" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r07.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=208077" title="스파이더맨: 노 웨이 홈">스파이더맨: 노 웨이 홈</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:88.19999694824219%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.82</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=208077">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="08" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r08.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=28876" title="화양연화">화양연화</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:88.00000190734863%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.80</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=28876">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="09" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r09.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=150198" title="너의 이름은.">너의 이름은.</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:88.00000190734863%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.80</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=150198">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="010" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_r10.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=19501" title="하나-비">하나-비</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:85.60000419616699%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.56</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=19501">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr><td class="line01" colspan="8"></td></tr>
# <tr>
# <td class="ac"><img alt="11" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g11.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=153964" title="목소리의 형태">목소리의 형태</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:84.79999542236328%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.48</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=153964">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="12" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g12.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=10546" title="아비정전">아비정전</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:84.49999809265137%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.45</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=10546">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="up" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_up_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="13" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g13.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=205623" title="드라이브 마이 카">드라이브 마이 카</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:84.39999580383301%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.44</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=205623">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="up" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_up_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="14" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g14.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=189118" title="광대: 소리꾼">광대: 소리꾼</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:84.30000305175781%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.43</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=189118">평점주기</a></td>
# <!----------------------------------------->
# <td class="new_icon" colspan="2"><img alt="new" height="5" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_new_1.gif" width="20"/></td>
# </tr>
# <tr>
# <td class="ac"><img alt="15" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g15.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=66820" title="초속5센티미터">초속5센티미터</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:83.59999656677246%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.36</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=66820">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="16" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g16.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=190991" title="이상한 나라의 수학자">이상한 나라의 수학자</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:83.29999923706055%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.33</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=190991">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="17" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g17.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=194813" title="어나더 라운드">어나더 라운드</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:83.00000190734863%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.30</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=194813">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="18" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g18.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=192143" title="나이트메어 앨리">나이트메어 앨리</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:81.19999885559082%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">8.12</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=192143">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="na" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/></td>
# <td class="range ac">0</td>
# </tr>
# <tr>
# <td class="ac"><img alt="19" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g19.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=181114" title="날씨의 아이">날씨의 아이</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:79.60000038146973%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.96</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=181114">평점주기</a></td>
# <!----------------------------------------->
# <td class="new_icon" colspan="2"><img alt="new" height="5" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_new_1.gif" width="20"/></td>
# </tr>
# <tr>
# <td class="ac"><img alt="20" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g20.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=191559" title="듄">듄</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:79.60000038146973%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.96</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=191559">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr><td class="line01" colspan="8"></td></tr>
# <tr>
# <td class="ac"><img alt="21" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g21.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=207921" title="스펜서">스펜서</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:77.30000019073486%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.73</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=207921">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="22" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g22.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=193857" title="파워 오브 도그">파워 오브 도그</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:76.50000095367432%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.65</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=193857">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="23" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g23.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=80737" title="언차티드">언차티드</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:76.30000114440918%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.63</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=80737">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="24" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g24.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=183862" title="뜨거운 피">뜨거운 피</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:74.80000019073486%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.48</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=183862">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="25" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g25.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=190695" title="모비우스">모비우스</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:73.00000190734863%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.30</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=190695">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="26" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g26.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=177366" title="킹메이커">킹메이커</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:72.8000020980835%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.28</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=177366">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="27" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g27.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=154282" title="더 배트맨">더 배트맨</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:72.60000228881836%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">7.26</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=154282">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="28" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g28.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=213903" title="문폴">문폴</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:52.60000228881836%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">5.26</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=213903">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr>
# <td class="ac"><img alt="29" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/common/bullet_r_g29.gif" width="14"/></td>
# <td class="title">
# <div class="tit5">
# <a href="/movie/bi/mi/basic.naver?code=209859" title="배니싱: 미제사건">배니싱: 미제사건</a>
# </div>
# </td>
# <!-- 평점순일 때 평점 추가하기  -->
# <td><div class="point_type_2"><div class="mask" style="width:44.20000076293945%"><img alt="" height="14" src="https://ssl.pstatic.net/imgmovie/2007/img/common/point_type_2_bg_on.gif" width="79"/></div></div></td>
# <td class="point">4.42</td>
# <td class="ac"><a class="txt_link" href="/movie/point/af/list.naver?st=mcode&amp;sword=209859">평점주기</a></td>
# <!----------------------------------------->
# <td class="ac"><img alt="down" class="arrow" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/></td>
# <td class="range ac">1</td>
# </tr>
# <tr><td class="blank01" colspan="8"></td></tr>
# </tbody>
# </table>
# <!-- 페이지 네비게이션 시작 -->
# <!-- 페이지 네비게이션 끝 -->
# <!-- //랭킹 리스트 -->
# <span class="txt_mark">※</span> <span class="txt_term">집계기준 : <strong>2022.04.07</strong>일 까지 네이버영화에 수록 된 영화의 관람 후 평점</span>
# <!-- 네이버 영화평점랭킹 선정방법 -->
# <div class="box_choice_way">
# <img alt="네이버 영화평점랭킹 선정방법" height="13" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_01.gif" width="154"/>
# <dl class="choice_way">
# <dt><img alt="집계기준" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_01_1.gif" width="39"/></dt><dd>전국기준 현재 상영되고 있는 영화 중 <em>평점 응답자가 <strong>300명</strong> 이상</em>인 경우</dd>
# <dt><img alt="집계기간" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_01_2.gif" width="40"/></dt><dd>전일까지의 누적 평점</dd>
# <dt><img alt="표본오차" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_01_3.gif" width="40"/></dt><dd><em>95% 신뢰수준에서 ±5.65</em></dd>
# </dl>
# <table cellpadding="0" cellspacing="0" class="choice_way_data">
# <col width="48"/><col width="73"/><col width="73"/><col width="73"/><col width="73"/><col width="73"/><col width="110"/>
# <tr>
# <th class="bgwhite" scope="row">구분</th>
# <td>N</td>
# <td>Range</td>
# <td>Minimum</td>
# <td>Maximum</td>
# <td>Mean</td>
# <td>Std.Deviation</td>
# </tr>
# <tr>
# <th class="bgwhite" scope="row">평점</th>
# <td class="range ac">26</td>
# <td class="range ac">4.39</td>
# <td class="range ac">4.75</td>
# <td class="range ac">9.14</td>
# <td class="range ac">7.59</td>
# <td class="range ac">7.59</td>
# </tr>
# </table>
# <dl class="choice_way_qna">
# <dt><img alt="왜 평점응답자를 300명 이상으로 정하나요?" height="12" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_02.gif" width="221"/></dt>
# <dd>일반적인 여론조사에서의 최소 응답자수가 300명이기 때문입니다.</dd>
# <dt><img alt="표본오차 95% 신뢰수준에서 ±5.65가 무슨 뜻인가요?" height="12" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_03.gif" width="271"/></dt>
# <dd>동일한 실험을 100번 했을 경우 95번은 ±5.65% 범위 내에서 동일한 결과가 나온다는 말입니다.</dd>
# <dt><img alt="Descriptive Statistics는 어떻게 보는건가요?" height="12" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/txt_movie_ranking_04.gif" width="234"/></dt>
# <dd>
# <ul>
# <li>N=Case의 숫자</li>
# <li>Range=응답자의 범위</li>
# <li>Minimum=최소 응답값</li>
# <li>Maximum=최대응답값</li>
# <li>Mean=평균</li>
# <li>Std.Deviation=표준편자</li>
# </ul>
# </dd>
# </dl>
# </div>
# <!-- //네이버 영화평점랭킹 선정방법 -->
# <!-- 탑버튼 -->
# <div class="go_top">
# <a href="#gnb_top"><img alt="TOP" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/common/btn_top.gif" width="30"/></a>
# </div>
# <!-- //탑버튼 -->
# <img alt="" class="clear" src="https://ssl.pstatic.net/imgmovie/2007/img/common/blank.gif"/>
# <!-- //Content Body -->
# <script src="/common/js/jindo2.js" type="text/javascript"></script>
# </div>
# <div id="assistant">
# <!-- 우측 메뉴 -->
# <!-- 영화 인기검색어 -->
# <div class="box_type_1 mb_8">
# <h3><img alt="영화 인기검색어" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/tlt_r_best_movie.gif" width="75"/></h3>
# <ul class="r_ranking">
# <li class="ranking01">
# <a class="b" href="/movie/bi/mi/basic.naver?code=190695" onclick="clickcr(this,'pop.list','190695','1',event);" title="모비우스"><span class="blind">1위</span>모비우스</a>
# <span class="rank">
# <img alt="순위 변동 없음" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/>0</span>
# <li class="ranking02">
# <a href="/movie/bi/mi/basic.naver?code=183862" onclick="clickcr(this,'pop.list','183862','2',event);" title="뜨거운 피"><span class="blind">2위</span>뜨거운 피</a>
# <span class="rank">
# <img alt="순위 변동 없음" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/>0</span>
# <li class="ranking03">
# <a href="/movie/bi/mi/basic.naver?code=214553" onclick="clickcr(this,'pop.list','214553','3',event);" title="앰뷸런스"><span class="blind">3위</span>앰뷸런스</a>
# <span class="rank">
# <img alt="순위 변동 없음" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/>0</span>
# <li class="ranking04">
# <a href="/movie/bi/mi/basic.naver?code=191020" onclick="clickcr(this,'pop.list','191020','4',event);" title="야차"><span class="blind">4위</span>야차</a>
# <span class="rank">
# <img alt="순위 상승" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_up_1.gif" width="7"/>3</span>
# <li class="ranking05">
# <a href="/movie/bi/mi/basic.naver?code=213903" onclick="clickcr(this,'pop.list','213903','5',event);" title="문폴"><span class="blind">5위</span>문폴</a>
# <span class="rank">
# <img alt="순위 하락" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/>1</span>
# </li></li></li></li></li></ul>
# <!--[D] 더보기 위치 이동 -->
# <a class="more" href="/movie/sdb/rank/rmovie.naver" onclick="clickcr(this,'pop.more','','',event);">더보기</a>
# <p class="term">2022.04.10</p>
# </div>
# <!-- 영화인 인기검색어 -->
# <div class="box_type_1 mb_8">
# <h3><img alt="영화인 인기검색어" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/super_db/tlt_r_best_star.gif" width="85"/></h3>
# <ul class="r_ranking">
# <li class="ranking01">
# <a class="b" href="/movie/bi/pi/basic.naver?st=1&amp;code=159385" onclick="clickcr(this,'peo.list','159385','1',event);" title="지안"><span class="blind">1위</span>지안</a>
# <span class="rank">
# <img alt="" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/>0</span>
# <li class="ranking02">
# <a href="/movie/bi/pi/basic.naver?st=1&amp;code=1328" onclick="clickcr(this,'peo.list','1328','2',event);" title="자레드 레토"><span class="blind">2위</span>자레드 레토</a>
# <span class="rank">
# <img alt="" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/>0</span>
# <li class="ranking03">
# <a href="/movie/bi/pi/basic.naver?st=1&amp;code=1063" onclick="clickcr(this,'peo.list','1063','3',event);" title="마이클 베이"><span class="blind">3위</span>마이클 베이</a>
# <span class="rank">
# <img alt="" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_na_1.gif" width="7"/>0</span>
# <li class="ranking04">
# <a href="/movie/bi/pi/basic.naver?st=1&amp;code=46767" onclick="clickcr(this,'peo.list','46767','4',event);" title="나현"><span class="blind">4위</span>나현</a>
# <span class="rank">
# <img alt="" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_up_1.gif" width="7"/>2</span>
# <li class="ranking05">
# <a href="/movie/bi/pi/basic.naver?st=1&amp;code=43943" onclick="clickcr(this,'peo.list','43943','5',event);" title="천명관"><span class="blind">5위</span>천명관</a>
# <span class="rank">
# <img alt="" height="10" src="https://ssl.pstatic.net/imgmovie/2007/img/common/icon_down_1.gif" width="7"/>1</span>
# </li></li></li></li></li></ul>
# <a class="more" href="/movie/sdb/rank/rpeople.naver" onclick="clickcr(this,'peo.more','','',event);">더보기</a>
# <p class="term">2022.04.10</p>
# </div>
# <!--티켓예매순-->
# <div class="box_type_1 mb_8">
# <h3><img alt="티켓예매순" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/running/tlt_r_reservation.gif" width="51"/></h3>
# <div id="reserveRanking0" style="display:block">
# <ul class="r_ranking">
# <li class="ranking01"><a class="b" href="/movie/bi/mi/basic.naver?code=190695" onclick="clickcr(this,'tck.list','190695','1',event);" title="모비우스"><span class="blind">1위</span>모비우스</a><span class="ratio check">58.44%</span></li>
# <li class="ranking02"><a href="/movie/bi/mi/basic.naver?code=183862" onclick="clickcr(this,'tck.list','183862','2',event);" title="뜨거운 피"><span class="blind">2위</span>뜨거운 피</a> <span class="ratio">11.69%</span></li>
# <li class="ranking03"><a href="/movie/bi/mi/basic.naver?code=207921" onclick="clickcr(this,'tck.list','207921','3',event);" title="스펜서"><span class="blind">3위</span>스펜서</a> <span class="ratio">5.19%</span></li>
# <li class="ranking04"><a href="/movie/bi/mi/basic.naver?code=213733" onclick="clickcr(this,'tck.list','213733','4',event);" title="극장판 주술회전 0"><span class="blind">4위</span>극장판 주술회전 0</a> <span class="ratio">4.55%</span></li>
# <li class="ranking05"><a href="/movie/bi/mi/basic.naver?code=190991" onclick="clickcr(this,'tck.list','190991','5',event);" title="이상한 나라의 수학자"><span class="blind">5위</span>이상한 나라의 수학자</a> <span class="ratio">3.9%</span></li>
# </ul>
# <a class="more" href="/movie/sdb/rank/rreserve.naver" id="ticketRankLink" onclick="clickcr(this,'tck.more','','',event);">더보기</a>
# <div class="term_1"><img alt="출처:YES24" height="12" src="https://ssl.pstatic.net/imgmovie/2007/img/common/txt_source_yes24_02.gif" width="54"/><div class="date">2022.04.11</div></div>
# </div>
# </div>
# <!--//티켓예매순-->
# <!--박스오피스-->
# <div class="box_type_1 mb_8">
# <h3><img alt="박스오피스" height="11" src="https://ssl.pstatic.net/imgmovie/2007/img/running/tlt_r_boxoffice.gif" width="51"/></h3>
# <ul class="r_ranking box">
# <li class="ranking01"><a class="b" href="/movie/bi/mi/basic.naver?code=212095" onclick="clickcr(this,'box.list','212095','1',event);" title="수퍼 소닉2"><span class="blind">1위</span>수퍼 소닉2</a> <span "="" class="ratio check"><em>111096</em> 명</span></li>
# <li class="ranking02"><a href="/movie/bi/mi/basic.naver?code=190695" onclick="clickcr(this,'box.list','190695','2',event);" title="모비우스"><span class="blind">2위</span>모비우스</a> <span class="ratio"><em>62508</em> 명</span></li>
# <li class="ranking03"><a href="/movie/bi/mi/basic.naver?code=214553" onclick="clickcr(this,'box.list','214553','3',event);" title="앰뷸런스"><span class="blind">3위</span>앰뷸런스</a> <span class="ratio"><em>53266</em> 명</span></li>
# <li class="ranking04"><a href="/movie/bi/mi/basic.naver?code=189137" onclick="clickcr(this,'box.list','189137','4',event);" title="스텔라"><span class="blind">4위</span>스텔라</a> <span class="ratio"><em>39285</em> 명</span></li>
# <li class="ranking05"><a href="/movie/bi/mi/basic.naver?code=193961" onclick="clickcr(this,'box.list','193961','5',event);" title="루이스 웨인: 사랑을 그린 고양이 화가"><span class="blind">5위</span>루이스 웨인: 사랑을 그린 고양이 화가</a> <span class="ratio"><em>16092</em> 명</span></li>
# </ul>
# <a class="more" href="/movie/sdb/rank/rboxoffice.naver" onclick="clickcr(this,'box.more','','',event);">더보기</a>
# <div class="term_1"><span class="cnt">주말관객 기준</span><div class="date">20220408-20220410</div></div>
# </div>
# <!--//박스오피스-->
# </div>
# <img alt="" class="clear" src="https://ssl.pstatic.net/imgmovie/2007/img/common/blank.gif"/>
# </div>
# <!-- //Content Body -->
# </div>
# </div>
# </div>
# <!-- //content -->
# </div>
# <!-- //container -->
# <!-- Footer -->
# <script src="/common/js/jindo/component/1.0.2/jindo.Component.js" type="text/javascript"></script>
# <script src="/common/js/jindo/component/1.0.2/jindo.UIComponent.js" type="text/javascript"></script>
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" onclick="clickcr(this, 'fot.agreement', '', '', event);" target="_blank">이용약관</a></li>
# <li><a href="http://www.naver.com/rules/privacy.html" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" onclick="clickcr(this, 'fot.disclaimer', '', '', event);" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">영화 고객센터</a></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <p class="info">
# 				사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 최수연</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp" onclick="clickcr(this, 'fot.bizinfo', '', '', event);">사업자등록정보 확인</a></span><br/>
# 				주소 : 경기도 성남시 분당구 불정로 6 네이버 그린팩토리 <span>대표전화 : 1588-3820</span>
# </p>
# <address>
# <a class="logo" href="https://www.navercorp.com" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/movie/2013/07/logo_naver.png" width="63"/></a>
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com" onclick="clickcr(this, 'fot.corp', '', '', event);" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <!-- //footer -->
# <script type="text/javascript">
#
# if (false) {
# 	var alertType = "NONE";
# 	var koreanTitle = "";
# 	var movieCode = "0";
# 	var userReserveCount = "0";
# 	var todayDatetime = "20220411102654";
# 	var endDatetimeAfterTwoDays = "00000000000000";
#
#
# 	if (movieCode > 0) {
# 		openWriteActualPointAlert (alertType, koreanTitle, movieCode, userReserveCount, todayDatetime, endDatetimeAfterTwoDays);
# 	}
# }
#
# function openWriteActualPointAlert (alertType, koreanTitle, movieCode, count, today, endDate) {
# 	if (alertType == "ONE" || alertType == "MORE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 " + koreanTitle + "에\n평점 등록 시 네이버페이 마일리지 500원 적립!\n지금 평점쓰기 메뉴로 이동하시겠습니까?")) {
# 			top.location.href = "http://movie.naver.com/movie/bi/mi/point.naver?code=" + movieCode;
# 		}
# 	}
#
# }
#
# function setCookieLastUserReserveDate(today, endDate) {
# 	var cookieForNotOpenActualPointPopup = jindo.$Cookie();
#
#
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveDatetime");
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveCheckDatetime");
#
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveDatetime", endDate, 9999, "movie.naver.com");
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveCheckDatetime", today, 9999, "movie.naver.com");
# }
#
# </script>
# <script type="text/javascript">
#
#
#
#
#
# 			var alertMessage = "지원되지 않는 브라우저로 서비스 이용에 제한이 있습니다.";
#
#
#
# 	function getBrowser() {
# 		var ua = navigator.userAgent;
# 		if (/NAVER/.test(ua)) {
# 			return "NAVER_APP";
# 		} else if (/IEMobile/.test(ua)) {
# 			return "INTERNET_EXPLORER_MOBILE";
# 		} else if (/MSIE/.test(ua) || /Trident/.test(ua)) {
# 			return "INTERNET_EXPLORER";
# 		} else if (/Firefox/.test(ua)) {
# 			return "FIREFOX";
# 		} else if (/Opera\//.test(ua) || /OPR\//.test(ua)) {
# 			return "OPERA";
# 		}  else if (/Swing\//.test(ua)) {
# 			return "SWING";
# 		} else if (/Chrome\//.test(ua) || /CriOS\//.test(ua)) {
# 			return "CHROME";
# 		} else if (/BAND\//.test(ua)) {
# 			return "BAND_APP";
# 		} else if (/FBAN\/FBIOS/.test(ua)) {
# 			return "FACEBOOK_APP";
# 		} else if (/Twitter/.test(ua)) {
# 			return "TWITTER_APP";
# 		} else if (/KAKAOTALK/.test(ua)) {
# 			return "KAKAOTALK_APP";
# 		} else if (/Android/.test(ua) && /Safari/.test(ua)) {
# 			return "ANDROID_INTERNET_APP";
# 		} else if (/Safari/.test(ua)) {
# 			return "SAFARI";
# 		}
#
# 		return "";
# 	}
#
# 	if (getBrowser() === "UNKNOWN" && jindo.$Cookie().get("notSupportBrowserAlert") != 'true') {
# 		alert(alertMessage);
# 		jindo.$Cookie().set("notSupportBrowserAlert", "true", "9999", "movie.naver.com");
# 	}
# </script>
# <script src="/common/js/lcslog.js" type="text/javascript"></script>
# <script src="/common/js/jindo/component/1.0.2/jindo.Component.min.js" type="text/javascript"></script>
# <script charset="UTF-8" src="/common/js/vendor/jindo.WatchInput.js" type="text/javascript"></script>
# <script charset="UTF-8" src="/common/js/lib/Core.js?20220406163047" type="text/javascript"></script>
# <script charset="UTF-8" src="/common/js/lib/LNB.js?20220406163047" type="text/javascript"></script>
# <script charset="UTF-8" src="/common/js/lib/Search.js?20220406163047" type="text/javascript"></script>
# <script type="text/javascript">
#
#     // nhn.movie.Search가 jindo 기반이어서 javascript로 전환함
#     if (document.addEventListener) {
#         document.addEventListener("DOMContentLoaded", function () {
#             document.removeEventListener("DOMContentLoaded", arguments.callee, false);
#             loadFooter();
#         }, false);
#     }
# // Internet Explorer
#     else if (document.attachEvent) {
#         // onreadystatechange 는 모든 브라우저가 반환
#         document.attachEvent("onreadystatechange", function () {
#             if (document.readyState == "complete" || document.readyState == 'loaded') {
#                 document.detachEvent("onreadystatechange", arguments.callee);
#                 loadFooter();
#             }
#         });
#     }
#
#     function loadFooter() {
#         var goNaver = document.getElementById("lnb_gonaver");
#         goNaver.addEventListener("focus", focusonNaverIcon, false);
#
#         // LNB - 사용처를 못 찾음
# //   	var oLNB = new nhn.movie.LNB();
#
#         // 상단 검색영역
#         var oSearch = new nhn.movie.Search({
#             area : "jSearchArea",
#             autosearch : "https://auto-movie.naver.com/ac?q_enc=UTF-8&st=1&r_lt=1&n_ext=1&t_koreng=1&r_format=json&r_enc=utf-8&r_unicode=0&r_escape=1&q=",
#             movelink : "/movie/bi/mi/basic.naver?code=",
#             peoplelink : "/movie/bi/pi/basic.naver?code="
#         });
#
#         getGNB();
#     }
#
#     function focusonNaverIcon(event) {
#         event.preventDefault();	// jindo.$Event.CANCEL_DEFAULT 와 동일한 기능으로 추측됨
#         document.getElementById('ipt_tx_srch').value= "";
#         document.getElementById('search_placeholder').style = "display:inline;";
#         if (document.getElementById('jAutoComplate') != undefined && document.getElementById('jAutoComplate') !== null) {
#             document.getElementById('jAutoComplate').style = "display:none;"
#         }
#     }
#
#
#     window.addEventListener('pageshow', function(event) { lcs_do(); });
#
#     document.addEventListener('click', function (event) {
#         var welSource = event.srcElement;	// jindo.$Element(oEvent.element);
#         if (!document.getElementById("gnb").contains(welSource)) {
#             gnbAllLayerClose();
#         }
#     });
# </script>
# <!-- //Footer -->
# </div>
# </body>
# </html>

# %%
print('영화 제목을 추출한다면 - ')
print()

soup.find('div' , attrs={'class' : 'tit5'}).a.get_text()
# Out:
# 영화 제목을 추출한다면 -
# '씽2게더'

# %%
print('평점을 추출한다면 - ')
soup.find('td' , attrs={'class' : 'point'}).get_text()
# Out:
# 평점을 추출한다면 -
# '9.40'

# %%
print('영화 제목과 평점을 이용한 프레임 작성 - ')

titles = soup.select('.tit5 a')
points = soup.select('.point')

movie_frm = pd.DataFrame({
    'title' : [ title.get_text() for title in titles ] , 
    'point' : [ point.get_text() for point in points]
})
movie_frm
# Out:
# 영화 제목과 평점을 이용한 프레임 작성 -
#             title point
# 0            씽2게더  9.40
# 1     패왕별희 디 오리지널  9.31
# 2      극장판 주술회전 0  9.26
# 3          해피 투게더  9.18
# 4              코다  9.15
# 5         아무도 모른다  8.87
# 6   스파이더맨: 노 웨이 홈  8.82
# 7            화양연화  8.80
# 8         너의 이름은.  8.80
# 9            하나-비  8.56
# 10        목소리의 형태  8.48
# 11           아비정전  8.45
# 12      드라이브 마이 카  8.44
# 13        광대: 소리꾼  8.43
# 14        초속5센티미터  8.36
# 15    이상한 나라의 수학자  8.33
# 16        어나더 라운드  8.30
# 17       나이트메어 앨리  8.12
# 18         날씨의 아이  7.96
# 19              듄  7.96
# 20            스펜서  7.73
# 21       파워 오브 도그  7.65
# 22           언차티드  7.63
# 23          뜨거운 피  7.48
# 24           모비우스  7.30
# 25           킹메이커  7.28
# 26          더 배트맨  7.26
# 27             문폴  5.26
# 28      배니싱: 미제사건  4.42

# %%
print('date_range() - 임의의 날짜를 생성해서 인덱스로 적용 - ')
movie_date = pd.date_range('2022-04-08' , periods = len(movie_frm) )
movie_frm['movie_date'] = movie_date
# Out:
# date_range() - 임의의 날짜를 생성해서 인덱스로 적용 -

# %%
movie_frm.index = movie_date

# %%
movie_frm.drop('movie_date' , axis = 1 , inplace = True)

# %%
movie_frm['point'] = movie_frm['point'].astype(float)

# %%
movie_frm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29 entries, 2022-04-08 to 2022-05-06
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   29 non-null     object
#  1   point   29 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 696.0+ bytes

# %%
movie_frm
# Out:
#                     title  point
# 2022-04-08           씽2게더   9.40
# 2022-04-09    패왕별희 디 오리지널   9.31
# 2022-04-10     극장판 주술회전 0   9.26
# 2022-04-11         해피 투게더   9.18
# 2022-04-12             코다   9.15
# 2022-04-13        아무도 모른다   8.87
# 2022-04-14  스파이더맨: 노 웨이 홈   8.82
# 2022-04-15           화양연화   8.80
# 2022-04-16        너의 이름은.   8.80
# 2022-04-17           하나-비   8.56
# 2022-04-18        목소리의 형태   8.48
# 2022-04-19           아비정전   8.45
# 2022-04-20      드라이브 마이 카   8.44
# 2022-04-21        광대: 소리꾼   8.43
# 2022-04-22        초속5센티미터   8.36
# 2022-04-23    이상한 나라의 수학자   8.33
# 2022-04-24        어나더 라운드   8.30
# 2022-04-25       나이트메어 앨리   8.12
# 2022-04-26         날씨의 아이   7.96
# 2022-04-27              듄   7.96
# 2022-04-28            스펜서   7.73
# 2022-04-29       파워 오브 도그   7.65
# 2022-04-30           언차티드   7.63
# 2022-05-01          뜨거운 피   7.48
# 2022-05-02           모비우스   7.30
# 2022-05-03           킹메이커   7.28
# 2022-05-04          더 배트맨   7.26
# 2022-05-05             문폴   5.26
# 2022-05-06      배니싱: 미제사건   4.42

# %%
print('선 그래프를 - 날짜별 포인트 시각화 - ')

plt.figure( figsize = (15, 5))



plt.plot(movie_frm.index , movie_frm['point'] , 
         c  = 'red' , 
         lw = '2' , 
         ls = '--' , 
         marker = 'o' , 
         ms = 7 , 
         mec = 'green' , 
         mew = 3,
         mfc = 'red')

plt.xlabel('x 축') 
plt.ylabel('y 축') 
plt.title('연습하는 라인플롯')
plt.show()
plt.close()
# Out:
# 선 그래프를 - 날짜별 포인트 시각화 -

# %%
print('평점이 높은 상위 5개의 영화평점을 막대그래프로 시각화 - ')

top5 = movie_frm.sort_values(by = 'point', ascending = False).head(5)
top5

sns.barplot(data = top5, x = top5['title'], y = top5['point'])
plt.show()
plt.close()

movie_frm_sub = movie_frm.sort_values(by = 'point', ascending=False).head(5)
movie_frm_sub.plot(kind = 'bar', x='title', y='point' , rot = -10)
# Out:
# 평점이 높은 상위 5개의 영화평점을 막대그래프로 시각화 -
# <AxesSubplot:xlabel='title'>

# %% [markdown]
# - https://www.imdb.com/title/tt4154756/reviews?ref_=tt_ql_3 [실습]
# - 점수(별점) , 리뷰제목, 작성자, 작성날짜, 리뷰내용   -> 데이터 프레임 생성

# %% [markdown]
# - 페이지 처리방법

# %%
from time    import sleep , time 
from random  import randint
from IPython.core.display import clear_output

# %%
start_time = time()
# start_time

requests = 0 

for idx in range(1, 8) :
    requests += 1 
    sleep( randint(1,6) ) 
    current_time = time()
    elapsed_time = current_time - start_time
    print('request : {} , frequency : {}'.format( requests , requests/elapsed_time))
    clear_output(wait = True)
# Out:
# request : 7 , frequency : 0.36688273916457914

# %%
try :
    html = urlopen('https://ad.search.naver.com/search.naver?where=ad&sm=svc_nrs&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&referenceId=hC%20KZlp0JXossB2Y/PGssssssks-488995&pagingIndex=1')
    # print(html.read())
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')
    print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="always" name="referrer"/>
# <title>파이썬 :: 네이버 검색광고</title>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220318/css/search.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/css/api_setkr_ad_ssl.css" rel="stylesheet" type="text/css"/>
# <script charset="UTF-8" src="https://ssl.pstatic.net/adimg3.search/js/clickcr.js" type="text/javascript"></script>
# <script charset="UTF-8" src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190221_1/js/jindo_1.5.3_171116.js?1" type="text/javascript"></script>
# <script charset="UTF-8" src="https://ssl.pstatic.net/adimg3.search/ac/nhn.autocomplete.component_130613.js" type="text/javascript"></script>
# <script charset="UTF-8" src="https://ssl.pstatic.net/adimg3.search/js/jindo_component.js" type="text/javascript"></script>
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#     function urlencode(q) {
#       return escape(q).replace(/\+/g, "%2B");
#     }
#     if (typeof (encodeURIComponent) != "function") {
#       encodeURIComponent = function (s) {
#         function toHex(n) {
#           var hexchars = "0123456789ABCDEF";
#           return "%" + hexchars.charAt(n >> 4) + hexchars.charAt(n & 0xF);
#         }
#
#         var es = "";
#         for (var i = 0; i < s.length;) {
#           var c = s.charCodeAt(i++);
#           if ((c & 0xF800) == 0xD800) {
#             var sc = s.charCodeAt(i++);
#             c = ((c - 0xD800) << 10) + (sc - 0xDC00) + 0x10000;
#           }
#           if (!(c & ~0x7F)) {
#             if ((c >= 65 && c <= 90) || (c >= 97 && c <= 122) || (c >= 48 && c <= 57) || (c >= 45 && c <= 46) || c == 95 || c == 33 || c == 126 || (c >= 39 && c <= 42))                                es += String.fromCharCode(c); else                            es += toHex(c);
#           } else if (!(c & ~0x7FF))                       es += toHex(0xC0 + (c >> 6)) + toHex(c & 0x3F); else if (!(c & ~0xFFFF))                        es += toHex(0xE0 + (c >> 12)) + toHex(0x80 + (c >> 6 & 0x3F)) + toHex(0x80 + (c & 0x3F)); else                    es += toHex(0xF0 + (c >> 18)) + toHex(0x80 + (c >> 12 & 0x3F)) + toHex(0x80 + (c >> 6 & 0x3F)) + toHex(0x80 + (c & 0x3F));
#         }
#         return es;
#       }
#     }</script>
# <script type="text/javascript">var nsc = 'svc.adsearch.all';
#   var gnb_service = 'ad.search';
#   var gnb_template = 'gnb_utf8';
#   var gnb_searchbox = 'off';
#   var gnb_shortnick = 'off';
#   jindo.$Fn(function () {
#     jindo.$Fn(function (e) {
#       var gnbLayer = jindo.$Element("gnb");
#       var eventElement = jindo.$Element(e.element);
#       if (eventElement.isChildOf(gnbLayer) == false) {
#         gnbAllLayerClose();
#       }
#     }).attach(document.body, "click");
#   }).attach(window, "load");
#   </script>
# <script type="text/javascript">
#     var ccsrv = "cc.naver.com";
#     var g_ssc = "svc.adsearch.all";
#     var g_query = "\uD30C\uC774\uC36C";
#     var g_pid = "hDMv8wqpkE8ssd0NOks-216780";
#     var g_sid = "HrVyuYwKMmeYRHij4zxRaJmt";
#     document.domain = "naver.com";
#   </script>
# </head>
# <body class="t" onload="getGNB();">
# <script src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_new/151012/js/lcslog_ssl.js" type="text/javascript"></script>
# <script type="text/javascript">lcs_do({'pid': "hDMv8wqpkE8ssd0NOks-216780"});</script>
# <div class="tx" id="fix_wrap">
# <div id="u_skip"><a href="#content"><span>본문으로 바로가기</span></a></div>
# <div class="moread_wrap" id="wrap">
# <div id="header">
# <div class="ws_search_wrap">
# <h1>
# <a href="https://www.naver.com" onclick="clickcr(this, 'STA.naverlogo','','',event);">
# <img alt="NAVER" src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190220/img/logo_naver.png"/>
# </a>
# </h1>
# <form action="?" id="search_form" method="get" name="searchad">
# <fieldset class="g_window">
# <legend>검색</legend>
# <div class="gbox"><span class="keyword">
# <input name="where" type="hidden" value="ad"/>
# <input class="box_window" id="nx_query" maxlength="255" name="query" title="검색" type="text" value="파이썬"/></span></div>
# <input alt="검색" class="btn_srch" onclick="clickcr(this, 'STA.search','','',event);" src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190220/img/btn_search.png" type="image"/>
# <a class="btn_srch" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=sta_hty.adsearch&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC" target="_blank">
# <img alt="통합검색" src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190220/img/btn_search2.png"/></a>
# <div id="nautocomplete">
# <span class="btn_arw">
# <a href="#" onclick="return false;">
# <span class="sp_ad triangleImg">
# <span class="blind">자동완성펼치가</span>
# </span>
# </a>
# </span>
# </div>
# <div style="position: absolute; left: 0px; top: 47px; z-index: 100;">
# <iframe frameborder="0" height="0" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" src="/pc/reatcmp.html" style="display: none;" title="자동완성" width="428"></iframe>
# </div>
# </fieldset>
# </form>
# <div class="ad_gnb_wrap">
# <div id="gnb">
# <script charset="utf-8" src="https://static.nid.naver.com/template/gnb_utf8.nhn" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript"> var smartSearch = null;
#     $Fn(function () {
#       smartSearch = new nhn.AjaxSuggestUS("nx_query", "autoFrame", {
#         url: 'https://ac.search.naver.com/nx/ac',
#         cookieName: "NaverSuggestUse",
#         listbox: "_resultBox",
#         sFromName: "searchad",
#         triangleBtn: "nautocomplete",
#         sListMaxLength: 73,
#         listMaxCount: 15,
#         request_type: "jsonp",
#         request_data: {
#           q: "{query}",
#           st: "100",
#           r_format: "json",
#           t_koreng: "1",
#           q_enc: "UTF-8",
#           r_enc: "UTF-8",
#           r_unicode: "0",
#           r_escape: "1",
#           frm: "ad"
#         },
#         aClickLog: ["tab_sug.pre", "tab_sug.suf", ""],
#         sTriangleUpOn: "https://ssl.pstatic.net/sstatic/search/images11/btn_atcmp_up_on.gif",
#         sTriangleUpOff: "https://ssl.pstatic.net/sstatic/search/images11/btn_atcmp_up_off.gif",
#         sTriangleDownOn: "https://ssl.pstatic.net/sstatic/search/images11/btn_atcmp_down_on.gif",
#         sTriangleDownOff: "https://ssl.pstatic.net/sstatic/search/images11/btn_atcmp_down_off.gif"
#       }).attach({
#                 actSubmit: function () {
#                   this._elForm.submit();
#                 }
#               })
#     }).attach(window, "load");</script>
# <hr/>
# <div class="search_result">
# <div class="result_wrap">
# <div class="inner">
# <strong class="title">검색결과 전체보기</strong>
# <span class="num_result">1-25 / 157건</span>
# <a class="link_register" href="https://saedu.naver.com/adbiz/searchad/intro.nhn" onclick="clickcr(this, 'sct.registration','','',event);" target="_blank">내 업체 등록하기</a>
# </div>
# </div>
# </div>
# <div id="container">
# <div id="content">
# <div class="ad_section section">
# <ol class="lst_type">
# <li class="lst ext_price type_image type_subtitle" num="0" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=M/GcpWPjvALl+//rTXiWmv///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000171591342','1',event);" target="_blank">
# <img alt="파이썬 시작하기, 유데미" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTExMjlfMjQg/MDAxNjM4MTY0NzY0NTUw.z-PlmeEKSSIWhJh67iGmsEDdWx2m_3N4CmVUz8Ggb8kg.sh9UYWzMV0USI_MPEEJQDwXn99ieE9uh2qQ_LicXyC4g.JPEG/468960-55b745b2-b506-42a6-9e40-7418320817b8.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=6O89eWxo75wwdrYwM69tIf///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000171591342','1',event);" target="_blank">파이썬 시작하기, 유데미</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=6O89eWxo75wwdrYwM69tIf///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000171591342','1',event);" target="_blank">글로벌 베스트 강의 추천</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=6O89eWxo75wwdrYwM69tIf///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000171591342','1',event);" target="_blank">https://www.udemy.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   글로벌 전문가의 <strong class="hl">파이썬</strong> 강의 오직 유데미에서만, 4천만 수강생 인증
#                 </p></div>
# <ul class="lst_price">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=5ePndVVyO+DLp7XYIP4x8f///w==..." onclick="clickcr(this, 'sct.pricelink1','nad-a001-01-000000171591342','1',event);" target="_blank">
# <span class="price">17,000원부터</span>
# <div class="txt">
# <span class="txt_inner">첫 구매시 모든 강의</span>
# </div>
# </a>
# </li>
# </ul>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">4~12개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="1" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=XcMxqrRUhEzwvLp4cQv7ov///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000171482563','2',event);" target="_blank">
# <img alt="메가스터디 IT 파이썬" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTA1MjdfMjA0/MDAxNjIyMDk1NDA5NDY5.54hmsU3GMPD4t30n42uRWDkXRQfTTlaNqrzIn3ilXJ8g.7ajBtr4kwsO9FeayouA7O66RkCHP-fX2jUNiP1Pvj9Yg.PNG/1657269-41c6b157-6b1d-42e4-a256-0bf1628cb721.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=7C/KY2zu5BsBjBVO+XbeDP///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000171482563','2',event);" target="_blank">메가스터디 IT 파이썬</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=7C/KY2zu5BsBjBVO+XbeDP///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000171482563','2',event);" target="_blank">NO.1 IT전문교육기관</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=7C/KY2zu5BsBjBVO+XbeDP///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000171482563','2',event);" target="_blank">http://megaitacademy.com/</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=LikBj3YYh73tcfuu15AXX////w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000171482563','2',event);" target="_blank">수강생인터뷰</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=RubNOnXzPj0KQo/JcWoLIv///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000171482563','2',event);" target="_blank">인기과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=aOrcnE4wo+wF8HYiJWyfF////w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000171482563','2',event);" target="_blank">수강료조회</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=z9+fv1JHuAU9i8EZ87opxf///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000171482563','2',event);" target="_blank">이벤트</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   빅데이터 기반 핵심언어!,1개월단기,5년우수훈련기관,무료청강,1:1교육,실무자직강
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">25~36개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="2" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=ztLYQME74NWiMRK/hDlyXv///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000175135458','3',event);" target="_blank">
# <img alt="그린컴퓨터아트학원공식홈페이지" class="image" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDdfMjgy/MDAxNTUxOTM2MDY0NTU2.FjwQIJIffEpRVFxkKfsX8ZkFqRAFA77Kn1MAzB3OoHYg.mvX2GE-aldtCDVYLoZIatyhk-mrZTc0YEPIuRAyyhbUg.JPEG/699114-6d89b46c-8f64-4320-94b2-49480d718570.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=FxT0eOZRJg6gEbhWGWEcOf///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000175135458','3',event);" target="_blank">그린컴퓨터아트학원공식홈페이지</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=FxT0eOZRJg6gEbhWGWEcOf///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000175135458','3',event);" target="_blank">고용노동부지정 우수훈련기관</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=FxT0eOZRJg6gEbhWGWEcOf///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000175135458','3',event);" target="_blank">http://www.greenart.co.kr</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="https://nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display: none;" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></span>
# </span>
# <span class="sp_ad ly_tail"></span>
# </a>
# </span>
# </span>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=SPcK/zRqEz07+p1BIgtNqv///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000175135458','3',event);" target="_blank">국비지원안내</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=XHazmZ9tVgssbNJs89KH3P///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000175135458','3',event);" target="_blank">추천교육과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=trZgq0w119GZxPVJKVERBf///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000175135458','3',event);" target="_blank">수강료조회</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=FtIelH4LAoiUKuETjdmlyP///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000175135458','3',event);" target="_blank">지점조회</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   사회공헌대상 고용노동부 장관상수상, 취준생&amp;직장인 국비 최대 100%, <strong class="hl">파이썬</strong>
# </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">61개월 이상</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span><span class="ico_bar w6"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="3" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=RPnzGuxhXPjqZ86/k489Wf///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000175329680','4',event);" target="_blank">
# <img alt="강남아이티아카데미학원" class="image" src="https://searchad-phinf.pstatic.net/MjAyMDEwMDVfMTMz/MDAxNjAxODc5MDUwODc0.J7h1pjWdTgtSS3DGuziKveLV8ramVXHI1rfFhfybamUg.NNbCwK7oxLvfN9mJJv7ELpBn1f8GFgr05AUODe5KHy8g.PNG/1298750-19a7cd76-9e48-4e6e-a32f-4737f344256b.PNG"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=unQnKoHm6hE+sxTXMC6Mlv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000175329680','4',event);" target="_blank">강남아이티아카데미학원</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=unQnKoHm6hE+sxTXMC6Mlv///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000175329680','4',event);" target="_blank"><strong class="hl">파이썬</strong>장고 백엔드웹개발교육원</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=unQnKoHm6hE+sxTXMC6Mlv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000175329680','4',event);" target="_blank">http://gnitac.co.kr/</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=yNaZN7ISTrQoZMZA+IHDsP///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000175329680','4',event);" target="_blank">연간교육일정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=yiOw5WJVbFH6YN5ybLGbHf///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000175329680','4',event);" target="_blank">취업지원안내</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=1ooylHnjY1NQSDg+P6Qhav///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000175329680','4',event);" target="_blank">포트폴리오</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=JarNaUsDoiL4DbiQAWI9D////w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000175329680','4',event);" target="_blank">학원위치</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   강남역, 국비최대100%, <strong class="hl">파이썬</strong> 웹개발 단기과정, 기초탄탄 취업과정, 취업연계.
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">13~24개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="4" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=xoWsXKgIJwx7u7l8yzPOBP///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000165924115','5',event);" target="_blank">
# <img alt="한국직업능력교육원 시흥캠퍼스" class="image" src="https://searchad-phinf.pstatic.net/MjAxODEyMTFfODcg/MDAxNTQ0NTEyMzg3NTI4.laD5gU210NvSdO8aGD_E3n9Nec0U_FM0d7kyAgI1gHEg.UEf9OGrYrkIpYYTL3Sifr-jpAour_KXntgGcnGqDf1gg.PNG/431723-5d0e11f0-ed61-45a5-a5cb-267feb30a1a4.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=idP2eUf7HAOoBni4vgomxv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000165924115','5',event);" target="_blank">한국직업능력교육원 시흥캠퍼스</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=idP2eUf7HAOoBni4vgomxv///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000165924115','5',event);" target="_blank">전국0.3% BEST훈련기관</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=idP2eUf7HAOoBni4vgomxv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000165924115','5',event);" target="_blank">http://www.ktechedu.com/siheung/</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=g86HvTq5LGJ6L5cAhfuCtf///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000165924115','5',event);" target="_blank">국비지원교육</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=jruMTZRz2wWVo2XZ6kCaBv///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000165924115','5',event);" target="_blank">교육일정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=Z0EyeIFFtb66Ivt10hXvbf///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000165924115','5',event);" target="_blank">온라인상담</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=ZkVkvvINzOQi+B6B/VHwCv///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000165924115','5',event);" target="_blank">교육시설</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   고용노동부 선정 BEST훈련기관(전국9개),취업에 강한 실무중심교육, 기숙사제공
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">37~60개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="5" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=mkGKX4t+2NUqtBs+2aVzrP///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000175272767','6',event);" target="_blank">
# <img alt="그린컴퓨터아카데미 강남캠퍼스" class="image" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDdfMTY1/MDAxNTUxOTM0ODAxNDEy.J3SRBbLzqGoq4Uunyq4ToRY9uQpH9pQq_0IAWIDRdssg.TBwESghatVY0pT0LrEZsVFmCcD4vXVANQ3cExac40fsg.JPEG/21977-3244f6e3-9afc-4646-b018-19493f3c3691.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=KXPAelUrdT1fdgOkKENlbv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000175272767','6',event);" target="_blank">그린컴퓨터아카데미 강남캠퍼스</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=KXPAelUrdT1fdgOkKENlbv///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000175272767','6',event);" target="_blank">사회공헌대상 고용노동부장관상</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=KXPAelUrdT1fdgOkKENlbv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000175272767','6',event);" target="_blank">http://gangnam.greenart.co.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=NHZyHuJl0ai0gftXsA409f///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000175272767','6',event);" target="_blank">추천교육과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=W7+mIiXR7OlCsZmyGKqhy////w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000175272767','6',event);" target="_blank">취업인터뷰</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=Q1LjfiMsRJqyTB88iGjYhP///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000175272767','6',event);" target="_blank">수강료조회</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=EZGv1U9QagHA7TG8MJz+A////w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000175272767','6',event);" target="_blank">학원위치</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   취준생&amp;직장인 국비 최대 100%, 1:1취업지원, 디자인IT 실무교육 <strong class="hl">파이썬</strong>
# </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">61개월 이상</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span><span class="ico_bar w6"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst" num="6" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=McOiuAmE92dmb5u2ecoGLv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000177762934','7',event);" target="_blank">IT커리어의 첫걸음, 불라방</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=McOiuAmE92dmb5u2ecoGLv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000177762934','7',event);" target="_blank">https://www.ybmlive.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   YBM 불라방 디지털 커리어 과정 OPEN
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">13~24개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst ext_desc type_image type_subtitle ext_link" num="7" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=7+zveNF26+sAbkVDyNRx5P///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000164962491','8',event);" target="_blank">
# <img alt="파이썬, 토폴라" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTExMzBfMTg4/MDAxNjM4MjU0NzUyNTE2.JSkj3HMeTtRYzeIiBU7cJfvhsbiEXhhkvNq7LIyTUKwg.j0P_garKIn5uh5VsWyxy1i_YCr_FHqzrv6XO7u4c0NIg.JPEG/1993263-1ca04700-7bf6-411c-9ecd-d45602a36fe2.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=956cy0jm7bzDF35GNUE5if///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000164962491','8',event);" target="_blank">파이썬, 토폴라</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=956cy0jm7bzDF35GNUE5if///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000164962491','8',event);" target="_blank">모두의 코딩 베이스캠프</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=956cy0jm7bzDF35GNUE5if///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000164962491','8',event);" target="_blank">http://www.topolar.co.kr</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="https://nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display: none;" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></span>
# </span>
# <span class="sp_ad ly_tail"></span>
# </a>
# </span>
# </span>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=DCtpG0H6ZUhC06wcInQ12P///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000164962491','8',event);" target="_blank">커리큘럼</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=/smEtYTt4n/qqkKHVjGMbf///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000164962491','8',event);" target="_blank">수강생 후기</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=+0T9GHAtJtWxX33Dw/iJgf///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000164962491','8',event);" target="_blank">무료체험수업</a></li>
# </ul>
# <p class="ad_dsc promotion">
# <em class="point">이벤트</em>
#                   자바스크립트 4주완성 특강
#                 </p>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   코딩기초전문 온라인 코딩과외! 배열, 리스트, 포인터등 막히는 개념 실시간 문답
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">13~24개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="8" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=lT8bou0kTMdlm0yb8zCRf////w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000145409279','9',event);" target="_blank">
# <img alt="52년 역사 중앙정보처리학원" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTA4MDZfMjMx/MDAxNjI4MjMxNDU2NzI5.vDmmp1j8BzQ4MNmD7yWzFzKP078asv6UOXCw8MvPyqYg.DQo0GcNKfj9eoNrXPk2QPkztmfSOMRBnO5yOBueWiOgg.PNG/2318894-3a05d8a6-ec35-485b-8022-ae9427796d6c.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=mXzVGoXkFrtKTT9TyUCm0////w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000145409279','9',event);" target="_blank">52년 역사 중앙정보처리학원</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=mXzVGoXkFrtKTT9TyUCm0////w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000145409279','9',event);" target="_blank">서울 본점</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=mXzVGoXkFrtKTT9TyUCm0////w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000145409279','9',event);" target="_blank">http://www.choongang.co.kr/</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=NHIzrDG1qBiNdL4XlgoAMP///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000145409279','9',event);" target="_blank">학원소개</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=QT8pHQI3Jk0WuaHLgmZTEf///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000145409279','9',event);" target="_blank">국민취업교육</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=fe2km30LhpzOHhztZ1oNPP///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000145409279','9',event);" target="_blank">내일배움카드</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=rOyavSaOlpGyS9Sbz7tHef///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000145409279','9',event);" target="_blank">찾아오시는길</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   Since1969 고용노동부 최우수 훈련기관 선정! 전액 국비지원 IT취업연계교육
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">4~12개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image ext_place type_subtitle ext_link" num="9" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=7xW8R2oED2+NsACUFWyPn////w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000170326699','10',event);" target="_blank">
# <img alt="구디아카데미 가산디지털단지점" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTA5MDFfMjYz/MDAxNjMwNDU4NTU2NzY2.qJdhIrE8k2jS2RITAS3OjnVsF4BMN0cupgE5SuryYE8g.d6qVIuGU4MziP8FwM0X8SUsi7ovhUOqy8K5iOni5JVMg.PNG/1128402-cba41880-cb43-4e9f-960b-c5e4199550dc.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=beW2rG3KGY2l6VULevnWif///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000170326699','10',event);" target="_blank">구디아카데미 가산디지털단지점</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=beW2rG3KGY2l6VULevnWif///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000170326699','10',event);" target="_blank">고용노동부인증 우수훈련기관</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=beW2rG3KGY2l6VULevnWif///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000170326699','10',event);" target="_blank">http://gdu.co.kr/</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=E8q94pOyqvENdW2jfkJ/m////w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000170326699','10',event);" target="_blank">교육과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=Otvf9s6QrpvJeZ75TdYvZP///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000170326699','10',event);" target="_blank">HRD만족도</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=RUeOBmV2y+7g8mk6fVap1f///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000170326699','10',event);" target="_blank">취업지원</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=daWBogevh2Kd6oJiZjyUmf///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000170326699','10',event);" target="_blank">시설안내</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   고용노동부 5년연속 우수훈련기관,100%무료국비,1:1취업지원,취업률만족도 만점
#                 </p></div>
# <a class="place_info" href="https://adcr.naver.com/adcr?x=Pjre+bmuK3T9qbcg3L318f///w==..." onclick="clickcr(this, 'sct.place','nad-a001-01-000000170326699','10',event);" target="_blank">
# <div class="keyword_area">
# <span class="item">자바학원</span><span class="item">네트워크학원</span><span class="item">스마트팩토리</span><span class="item">IT국비지원</span>
# </div>
# <div class="etc_area">
# <span class="item">방문자리뷰 1</span>
# </div>
# </a>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">37~60개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="10" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=7zPgt5tKzUmUIkq9m6qB9P///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000175725199','11',event);" target="_blank">
# <img alt="K디지털 에이콘아카데미 종로" class="image" src="https://searchad-phinf.pstatic.net/MjAyMDAyMDdfNDMg/MDAxNTgxMDM3Mjc5Mzcw.xR00tE3Xn-x9Ai_qH5j2L8xJ0pv97arpUtYZDAvfQNog.qPM6i2qFsnRVBuxukA3Hh_nfFUZter_VFZl0jLnJhsUg.PNG/1845641-a24013b9-bdbf-4ee0-912c-0b61f26f6072.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=ROh0YWP2cgj4dtWOkUiPdv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000175725199','11',event);" target="_blank">K디지털 에이콘아카데미 종로</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=ROh0YWP2cgj4dtWOkUiPdv///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000175725199','11',event);" target="_blank">정부지원 전액무료</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=ROh0YWP2cgj4dtWOkUiPdv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000175725199','11',event);" target="_blank">http://www.acorncampus.co.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=GNHabeAklRqAtIL4yx3CuP///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000175725199','11',event);" target="_blank">아카데미소개</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=/8QfvNBTY9kvGiAVqAgUV////w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000175725199','11',event);" target="_blank">국비지원과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=SzgwruJUeByav3Nu+b+SAv///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000175725199','11',event);" target="_blank">취업생인터뷰</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=2cByfvGTkxR1x/c4U/q18P///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000175725199','11',event);" target="_blank">위치</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   국비 100%무료교육, 빅데이터, 자바웹개발, 프론트엔드, IT학원 <strong class="hl">파이썬</strong>
# </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">25~36개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_subtitle ext_link" num="11" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=vyvcXZp8SFQOEuHeGygdrP///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000172350656','12',event);" target="_blank">K-디지털크레딧 패스트캠퍼스</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=vyvcXZp8SFQOEuHeGygdrP///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000172350656','12',event);" target="_blank"> 사용료 90% 정부지원! </a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=vyvcXZp8SFQOEuHeGygdrP///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000172350656','12',event);" target="_blank">https://fastcampus.co.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=SsuSJ51f/7DcQW8v2MHW3f///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000172350656','12',event);" target="_blank">기업교육소개</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=PfJzcKxSzEVV+DLtDdMVkf///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000172350656','12',event);" target="_blank">비대면바우처</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=XdBVbRSkYCQYkiSEEfOJ8f///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000172350656','12',event);" target="_blank">상담신청문의</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=Garb429S0PCwWySgvjSVuv///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000172350656','12',event);" target="_blank">신청방법안내</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   빅데이터, AI, 개발 과정을 국비지원으로 배울 수 있는 절호의 기회.
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">4~12개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="12" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=Rri8Zdhf9GFKw87GSbplF////w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000173888872','13',event);" target="_blank">
# <img alt="에듀윌 국비교육원" class="image" src="https://searchad-phinf.pstatic.net/MjAyMjAxMDZfMTQ1/MDAxNjQxNDU4MDUxODE3.qM6rMBerBprz1EG_DkMz5QvYKupimq9SAQZxrlAF2Qkg.GeLdtkqtv0NXeQrac_yk1edTWGVbf2310e1FbNH7jM4g.PNG/4273-4f49fd36-2330-42c6-bb07-c820c9e3cd0c.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=N46MD8RAc49e733faYHvgv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000173888872','13',event);" target="_blank">에듀윌 국비교육원</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=N46MD8RAc49e733faYHvgv///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000173888872','13',event);" target="_blank">무료상담신청</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=N46MD8RAc49e733faYHvgv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000173888872','13',event);" target="_blank">https://snh.eduwill.net</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=GLi4CB2q7NUNsOhPC0gB1////w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000173888872','13',event);" target="_blank">구로센터</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=Muwe9wyjtCVoAoION3Zz0////w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000173888872','13',event);" target="_blank">성남센터</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=yuWUDsVOe1tQNH8cecInPP///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000173888872','13',event);" target="_blank">부평센터</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=7HQ1gaUqVXwAKJYDVmuu7f///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000173888872','13',event);" target="_blank">무료상담신청</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   국비교육도 에듀윌! IT,자바, 게임 프로그래밍 다양한 교육과정 제공, 무료상담
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">4~12개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="13" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=UKY9du7wx7JJKzNaIbp//P///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000157288575','14',event);" target="_blank">
# <img alt="코리아IT아카데미 김태호" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTEyMDRfMjc1/MDAxNjM4NTg2NzU3OTgw._iGAQ-TitIoTPmzpapv3YOkImm2u6jRS3zvyv3GyRTwg.prvc0ZZmWxI8-nPgdap8j5X_r9NRIwBlg1r-tcTgy7Yg.JPEG/1047177-906e5262-591f-4b84-92a5-37f6b4ca147c.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=6qeQHrJ+EFecALxYqqUMU////w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000157288575','14',event);" target="_blank">코리아IT아카데미 김태호</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=6qeQHrJ+EFecALxYqqUMU////w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000157288575','14',event);" target="_blank">취업률 100% 도전</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=6qeQHrJ+EFecALxYqqUMU////w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000157288575','14',event);" target="_blank">http://dj-kitaca.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=TXntVf06xqbFbz/KCeqMUf///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000157288575','14',event);" target="_blank">수강료조회</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=SNBxkf/RJcNyZQlnGXgfH////w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000157288575','14',event);" target="_blank">교육과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=i/5oAtLjCTjRXlf+RHbbN////w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000157288575','14',event);" target="_blank">수강후기</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=Dj0x9DcR+81y2kJu3iDXXP///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000157288575','14',event);" target="_blank">프로젝트</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">파이썬</strong>, 1:1 학사지원, 온&amp;오프 강의 진행, 취업/진학/진로 상담
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">4~12개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst ext_price type_image type_subtitle ext_link" num="14" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=55i8fr7kLnhLGUPt+aLb4////w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000159395986','15',event);" target="_blank">
# <img alt="더조은컴퓨터아카데미 공식" class="image" src="https://searchad-phinf.pstatic.net/MjAyMDA1MjZfNDgg/MDAxNTkwNDYzMDM5ODMw.oxvRa1oL0aUfutsEIrWg6z9SUnqK6kgdAwnoSlDGJoYg.Uzcii9RHkp54PCiY5zrpquvd4z_MDeznuFO34ktEFukg.JPEG/8071-9bd2445f-2e24-45f4-84aa-e4c8630ab0a4.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=hWpMRORCQfPM+n7o1E4ghP///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000159395986','15',event);" target="_blank">더조은컴퓨터아카데미 공식</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=hWpMRORCQfPM+n7o1E4ghP///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000159395986','15',event);" target="_blank">수강생 취업률 100% 달성</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=hWpMRORCQfPM+n7o1E4ghP///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000159395986','15',event);" target="_blank">http://www.tjoeun.co.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=z/BqK5JhH7uo1B2PtJ4K/f///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000159395986','15',event);" target="_blank">국비대상조회</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=ZzlKPjHxR/OcXGEWO+SgAf///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000159395986','15',event);" target="_blank">교육과정</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=FFy39ViUuxqX9/0SZXI6M////w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000159395986','15',event);" target="_blank">포트폴리오</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=DHQMFgQobw4wTA4dyK5vxf///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000159395986','15',event);" target="_blank">개강일정</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   국비지원무료교육, 매월 훈련장려금 지급, C언어, 자바, <strong class="hl">파이썬</strong>, 비전공자도 가능
#                 </p></div>
# <ul class="lst_price">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=1RDEXQMeGh8db+BppQXGHf///w==..." onclick="clickcr(this, 'sct.pricelink1','nad-a001-01-000000159395986','15',event);" target="_blank">
# <span class="price">1원</span>
# <div class="txt">
# <span class="txt_inner">국비지원 무료교육</span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=SDDfsetHE5YPQv3lQQqnzf///w==..." onclick="clickcr(this, 'sct.pricelink2','nad-a001-01-000000159395986','15',event);" target="_blank">
# <span class="price">1원</span>
# <div class="txt">
# <span class="txt_inner">맞춤 교육상담 컨설팅</span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=AD4kXmuzLBsL5gYmDp/mj////w==..." onclick="clickcr(this, 'sct.pricelink3','nad-a001-01-000000159395986','15',event);" target="_blank">
# <span class="price">1원</span>
# <div class="txt">
# <span class="txt_inner">선착순 특강&amp;세미나</span>
# </div>
# </a>
# </li>
# </ul>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">61개월 이상</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span><span class="ico_bar w6"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="15" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# ...
# <span class="price">1원</span>
# <div class="txt">
# <span class="txt_inner">취업센터 무료상담</span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=zzC20guQXjNOWR2NV/ReVv///w==..." onclick="clickcr(this, 'sct.pricelink3','nad-a001-01-000000175636637','21',event);" target="_blank">
# <span class="price">1원</span>
# <div class="txt">
# <span class="txt_inner">포트폴리오 무료상담</span>
# </div>
# </a>
# </li>
# </ul>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">37~60개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="21" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=9H2QYGEnh/eDC5UTQ2rNbf///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000127804159','22',event);" target="_blank">
# <img alt="카페24 파이썬" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTA2MjFfMjQ5/MDAxNjI0MjQxMzM5MjY2.L2rypflPVFn6_UqXSz0xfq5V1wQ7YJC9CWp9HEHE-Bgg.jx0mGfnExSks4CUmlXxREi_CH9QHXdNnzk9wuSQQ3icg.PNG/130913-c88357f2-13ee-430b-9b40-4181f51c873a.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=c5bc9ie1NNia8gGrjrHuTf///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000127804159','22',event);" target="_blank">카페24 파이썬</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=c5bc9ie1NNia8gGrjrHuTf///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000127804159','22',event);" target="_blank">AI를 위한 고성능 GPU</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=c5bc9ie1NNia8gGrjrHuTf///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000127804159','22',event);" target="_blank">https://hosting.cafe24.com</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=m0s1+1vCn2CvwPEcPzBy+P///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000127804159','22',event);" target="_blank">웹호스팅</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=J+glRRrdSsOR8Lu+XEUzS////w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000127804159','22',event);" target="_blank">서버호스팅</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=3cc6OZbeDlh89mBbgObENf///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000127804159','22',event);" target="_blank">클라우드</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=9pQc9zutE2UEpgozd/2HJv///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000127804159','22',event);" target="_blank">인공지능AI</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   업계 최고의 기술력과 노하우! 합리적 가격! 결제 즉시 사용 가능!
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">13~24개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image ext_link" num="22" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=0He9YPwyp4wW1OmkQVK+b////w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000134204765','23',event);" target="_blank">
# <img alt="대한상공회의소 충남인력개발원" class="image" src="https://searchad-phinf.pstatic.net/MjAyMTExMDVfMjA2/MDAxNjM2MTAwMjkyNDk5.L7mMGVv5bHS1GA6Wyw8b8cS-GCQJpp41k7BRLKrx-8Qg.wCCcdEgYRtAhC3AeU0zIzcMTZ6PCh8Tpr-2IFfNBPxwg.PNG/1121519-27479258-2ba2-4753-8a0f-051fed5ea2d0.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=Kg8Ff7JEuW2u9WifWttwov///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000134204765','23',event);" target="_blank">대한상공회의소 충남인력개발원</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=Kg8Ff7JEuW2u9WifWttwov///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000134204765','23',event);" target="_blank">http://cn.korchamhrd.net</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=7R+Oiy1fXPcdXQdZx++gwv///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000134204765','23',event);" target="_blank">대전교육센터</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=t84ykW0BhkVTCX08b28Rev///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000134204765','23',event);" target="_blank">취업우수사례</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=29O6i2NDb4muztvVhLgQ0////w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000134204765','23',event);" target="_blank">개발원소개</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=+Bh9Rkg9vm9bhns3OpppKf///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000134204765','23',event);" target="_blank">입학상담</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   청년층 취업을 위한 직업훈련기관, 취업우수, 산업기사, 4차산업과정, 자동화시스템
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">37~60개월</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="23" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=E04Iq5eofk3K9jdFOAOsuP///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000104846766','24',event);" target="_blank">
# <img alt="국비IT교육 KH정보교육원" class="image" src="https://searchad-phinf.pstatic.net/MjAxODAxMzFfMTg1/MDAxNTE3MzU5MTE4OTA0.zH-ydzNcSC3CKgBMOIrF9jE_mAJW30YsdSBXppVjv2Eg.ETrUDTCs6bsuYAiwB1F69OF83_lyq_tYvH3AgL-FDgsg.JPEG/370925-d1e48b33-3094-4d3a-b0e9-5c480d574677.jpg"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=uCkBRn/kU0G83WzJK8r/rf///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000104846766','24',event);" target="_blank">국비IT교육 KH정보교육원</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=uCkBRn/kU0G83WzJK8r/rf///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000104846766','24',event);" target="_blank">100% 국비지원 무료교육</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=uCkBRn/kU0G83WzJK8r/rf///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000104846766','24',event);" target="_blank">http://www.iei.or.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=6KDhccS0RxzuO8w4Rakgff///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000104846766','24',event);" target="_blank">국비지원조회</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=jxTu0aGtb4rbeG0R2MTZ1////w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000104846766','24',event);" target="_blank">정보보안전문</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=QgFhPPa5Z6zLxSBUqvXAyP///w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000104846766','24',event);" target="_blank">취업지원센터</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=P5XSr775PiEj56h+Q6QOfv///w==..." onclick="clickcr(this, 'sct.sublink4','nad-a001-01-000000104846766','24',event);" target="_blank">무료교육상담</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#                   실업자 국비지원 전액무료, IT국비지원교육센터, 자바프로그래머, 정보보안전문가.
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">61개월 이상</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span><span class="ico_bar w6"></span>
# </span>
# </div>
# </div>
# </li>
# <li class="lst type_image type_subtitle ext_link" num="24" onmouseout="jindo.$Element(this).removeClass('selected');" onmouseover="jindo.$Element(this).addClass('selected');">
# <div class="ad_thumb">
# <a href="https://adcr.naver.com/adcr?x=tJ022tvql8r+genbQQ6lev///w==..." onclick="clickcr(this, 'sct.powerlinkimage','nad-a001-01-000000172021558','25',event);" target="_blank">
# <img alt="코드잇 파이썬" class="image" src="https://searchad-phinf.pstatic.net/MjAyMDA1MTRfOTUg/MDAxNTg5NDQ4NTA5MTM2.OqxX3RvGlPnxQkscss03QV3Q6nF2onka7WLqUxvS5Twg.YR0w5oJmFLjTem1EDvye51wM5Fs6vdib3suqXf0lboog.PNG/1099121-4002c8c9-0f6d-4559-88df-a63311712a20.png"/>
# </a>
# </div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=2IbAd8DhBwtXs9CX9cnjAv///w==...&amp;p=0" onclick="clickcr(this, 'sct.tit','nad-a001-01-000000172021558','25',event);" target="_blank">코드잇 파이썬</a>
# <a class="sub_tit" href="https://adcr.naver.com/adcr?x=2IbAd8DhBwtXs9CX9cnjAv///w==..." onclick="clickcr(this, 'sct.title2','nad-a001-01-000000172021558','25',event);" target="_blank">월 3만원대로 무제한 수강</a>
# <div class="url_area">
# <a class="url" href="https://adcr.naver.com/adcr?x=2IbAd8DhBwtXs9CX9cnjAv///w==...&amp;p=1" onclick="clickcr(this, 'sct.url','nad-a001-01-000000172021558','25',event);" target="_blank">http://www.codeit.kr</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="https://nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display: none;" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></span>
# </span>
# <span class="sp_ad ly_tail"></span>
# </a>
# </span>
# </span>
# </div>
# <ul class="lst_link">
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=jxpEFJtKuSohftTCVaWyef///w==..." onclick="clickcr(this, 'sct.sublink1','nad-a001-01-000000172021558','25',event);" target="_blank">추천커리큘럼</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=4ZtzNR5vRZT7IQerbhVJQP///w==..." onclick="clickcr(this, 'sct.sublink2','nad-a001-01-000000172021558','25',event);" target="_blank">리얼수강후기</a></li>
# <li class="item"><a class="link" href="https://adcr.naver.com/adcr?x=hoybYzAFt6VfvjxzyAEiB////w==..." onclick="clickcr(this, 'sct.sublink3','nad-a001-01-000000172021558','25',event);" target="_blank">무제한멤버십</a></li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">파이썬</strong>의 모든 것, 코드잇과 함께 기초부터 심화까지 하루 10분으로 마스터!
#                 </p></div>
# <div class="period_area">
# <span class="tit">광고집행기간</span>
# <em class="txt">61개월 이상</em>
# <span class="bar_period">
# <span class="ico_bar w1"></span><span class="ico_bar w2"></span><span class="ico_bar w3"></span><span class="ico_bar w4"></span><span class="ico_bar w5"></span><span class="ico_bar w6"></span>
# </span>
# </div>
# </div>
# </li>
# </ol>
# <div class="paginate">
# <strong>1</strong>
# <a href="?where=ad&amp;sm=svc_nrs&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hC KZlp0JXossB2Y/PGssssssks-488995&amp;pagingIndex=2" onclick="clickcr(this, 'sct.page','','2',event);">2</a>
# <a href="?where=ad&amp;sm=svc_nrs&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hC KZlp0JXossB2Y/PGssssssks-488995&amp;pagingIndex=3" onclick="clickcr(this, 'sct.page','','3',event);">3</a>
# <a href="?where=ad&amp;sm=svc_nrs&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hC KZlp0JXossB2Y/PGssssssks-488995&amp;pagingIndex=4" onclick="clickcr(this, 'sct.page','','4',event);">4</a>
# <a href="?where=ad&amp;sm=svc_nrs&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hC KZlp0JXossB2Y/PGssssssks-488995&amp;pagingIndex=5" onclick="clickcr(this, 'sct.page','','5',event);">5</a>
# <a href="?where=ad&amp;sm=svc_nrs&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hC KZlp0JXossB2Y/PGssssssks-488995&amp;pagingIndex=6" onclick="clickcr(this, 'sct.page','','6',event);">6</a>
# <a class="next" href="?where=ad&amp;sm=svc_nrs&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hC KZlp0JXossB2Y/PGssssssks-488995&amp;pagingIndex=2" onclick="clickcr(this, 'sct.page','','2',event);">다음페이지</a>
# </div>
# </div>
# <a class="banner_ad" href="https://saedu.naver.com/adbiz/searchad/intro.nhn">
# <img alt="네이버 검색광고,4천만 이용자에게 여러분의 비즈니스를 소개하고 싶다면 지금 가입해주세요." src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190218/img/banner_adsearch.png"/>
# </a>
# </div>
# <hr/>
# </div>
# <hr/>
# <div id="footer">
# <div class="ws_search_wrap">
# <form action="?" method="get" name="searchu">
# <fieldset class="g_window">
# <legend>검색</legend>
# <div class="gbox"><span class="keyword"><input name="where" type="hidden" value="ad"/>
# <input maxlength="255" name="query" title="검색" type="text" value="파이썬"/></span>
# </div>
# <input alt="검색" class="btn_srch" onclick="clickcr(this, 'fot.search','','',event);" src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190220/img/btn_search.png" type="image"/>
# <a class="btn_srch" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=sta_hty.adsearch&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC" onclick="clickcr(this, 'fot.nx','','',event);" target="_blank">
# <a class="btn_srch" href="#">
# <img alt="통합검색" src="https://ssl.pstatic.net/adimg3.search/imp/nx/moread/power_contents/190220/img/btn_search2.png"/>
# </a>
# </a></fieldset>
# </form>
# </div>
# <ul>
# <li class="first">
# <a href="https://saedu.naver.com/help/faq/ncc/index.nhn" onclick="clickcr(this, 'fot.help','','',event);" target="_blank">검색광고 도움말</a>
# </li>
# <li>
# <a href="https://help.naver.com/customer/etc/webDocument.nhn" onclick="clickcr(this, 'fot.policy','','',event);" target="_blank">웹문서 수집 및 삭제 정책</a>
# </li>
# <li>
# <a href="https://help.naver.com/" onclick="clickcr(this, 'fot.helpdesk','','',event);" target="_blank">고객센터</a>
# </li>
# </ul>
# <address>
# <a class="corp" href="https://www.navercorp.com/" onclick="clickcr(this, 'fot.navercorp','','',event);" target="_blank"><em>©</em> NAVER Corp.</a>
# </address>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   (function () {
#     var needFix = navigator.userAgent.toLowerCase().indexOf('webkit') > -1;
#     d = document;
#     if (!needFix || !d.querySelectorAll) return;
#     var toArray = function (list) {
#       var armap = [];
#       i = 0;
#       for (; i < list.length; ++i) {
#         armap.push(list[i]);
#       }
#       return Array.prototype.slice.call(armap, 0);
#     };
#     window.addEventListener('load', function () {
#       toArray(d.querySelectorAll('#u_skip a')).forEach(function (el) {
#         el.addEventListener('click', function () {
#           var target = d.getElementById(this.href.split('#')[1]);
#           oldTabIndex = target.getAttribute('tabindex');
#           oldOutlineWidth = d.defaultView.getComputedStyle(target, null).getPropertyValue('outline-width');
#           target.setAttribute('tabindex', 0);
#           target.style.outlineWidth = 0;
#           target.focus();
#           if (oldTabIndex === null) target.removeAttribute('tabindex'); else target.setAttribute('tabindex', oldTabIndex);
#         }, false);
#       });
#     }, false);
#   })();
# </script>
# </body>
# </html>

# %%
soup.select('.lnk_tit')[0].get_text()
# Out:
# '파이썬 시작하기, 유데미'

# %%
pages = [ str(i) for i in range(1, 8) ]
pages
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
start_time = time()
# start_time

requests = 0 

title_lst = []

for page in pages :
    
    html = urlopen('https://ad.search.naver.com/search.naver?where=ad&sm=svc_nrs&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&referenceId=hC%20KZlp0JXossB2Y/PGssssssks-488995&pagingIndex='+page)
    soup = BeautifulSoup(html.read() , 'html.parser')
    
    title_txt = [ a.get_text() for a in soup.select('.lnk_tit') ]
    title_lst.extend( title_txt ) 
    
    requests += 1
    sleep( randint(1,3 ) ) 
    current_time = time()
    elapsed_time = current_time - start_time
    print('request : {} , frequency : {}'.format( requests , requests/elapsed_time))
    clear_output(wait = True)
# Out:
# request : 7 , frequency : 0.5445063471526254

# %%
title_lst
# Out:
# ['파이썬 시작하기, 유데미',
#  '메가스터디 IT 파이썬',
#  '그린컴퓨터아트학원공식홈페이지',
#  '강남아이티아카데미학원',
#  '한국직업능력교육원 시흥캠퍼스',
#  '그린컴퓨터아카데미 강남캠퍼스',
#  'IT커리어의 첫걸음, 불라방',
#  '파이썬, 토폴라',
#  '52년 역사 중앙정보처리학원',
#  '구디아카데미 가산디지털단지점',
#  'K디지털 에이콘아카데미 종로',
#  'K-디지털크레딧 패스트캠퍼스',
#  '에듀윌 국비교육원',
#  '코리아IT아카데미 김태호',
#  '더조은컴퓨터아카데미 공식',
#  '코리아IT아카데미 김한별',
#  'SBS아카데미컴퓨터아트학원',
#  '빅데이터&핀테크 취업특화교육',
#  '쌍용교육센터 공식홈페이지',
#  '코딩을 창작하다, 위즈라이브',
#  '아텐츠 게임아카데미 강남본점',
#  '카페24 파이썬',
#  '대한상공회의소 충남인력개발원',
#  '국비IT교육 KH정보교육원',
#  '코드잇 파이썬',
#  '강남 그린컴퓨터아카데미',
#  'KG아이티뱅크 취업교육센터',
#  '브랜뉴디자인아카데미',
#  '파이썬, 한직교 안산',
#  '비전공자도가능, 저스트 코드',
#  '대한상공회의소서울기술교육센터',
#  '가비아 컨테이너 호스팅',
#  '100%무료교육 휴먼교육센터',
#  'IT전문교육 IT뱅크 김서균',
#  '억대 연봉 빅데이터 강의',
#  '그로우 파이썬 주식분석',
#  '파이썬 와이즈코딩',
#  '한국소프트웨어인재개발원',
#  '구로 오라클자바교육센터',
#  '어소트락 파이썬',
#  'KG에듀원 KG아이티뱅크',
#  '대학인강 대표 유니와이즈',
#  '코리아IT아카데미 문제근',
#  '개발자 IT특강 에컴클래스',
#  '프로가되는 온라인강의 인프런',
#  '쿨사인 파이썬 AI개발',
#  'SBS아카데미컴퓨터학원이지일',
#  '파이썬 모든에듀',
#  '1-2년차 PM으로 성장하기',
#  '파이썬 인강 아이티동스쿨',
#  '파이썬 인강 인터넷강의',
#  '파이썬전문학원 이유진 샘!',
#  '비전공자를 위한 파이썬',
#  '코리아IT아카데미 김학훈',
#  'IT뱅크 스터디팀 상담 김구',
#  'SBS아카데미컴퓨터학원노재림',
#  '파이썬 옥션',
#  '로봇클럽 코딩클럽',
#  '파이썬 클래스101',
#  '비전공자를 위한 파이썬과정',
#  '라인트레이서파이썬',
#  'ALLCO올어바웃코딩부트캠프',
#  '파이썬 아웃소싱, 크몽',
#  '파이썬추천학원 이젠아카데미',
#  '즉각 실무적용! 파이썬',
#  '스파르타코딩클럽 파이썬강의',
#  '이공계IT전문기술연수-이젠',
#  'G마켓 파이썬',
#  'KG아이티뱅크 진정헌',
#  '쿠팡 파이썬',
#  'KGITBANK교육문의안여주',
#  '용인 소프트파워컴퓨터학원',
#  'SBS아카데미컴퓨터학원진예라',
#  '파이썬 씨스꿀',
#  '파이썬, 롯데ON',
#  '파이썬 방문교육 에듀밍코리아',
#  'IT뱅크 파이썬학원 김영재',
#  '파이썬 교보문고',
#  'SBS아카데미컴퓨터학원김수현',
#  '파이썬 컴알',
#  'SW코딩교육 / AI코딩교육',
#  '파이썬전문교육 신율기',
#  '사업자용 파이썬 나비엠알오',
#  '한국정보교육원',
#  'OpenCV AI Kit',
#  'KG아이티뱅크 김수현',
#  '업무실무도 프립이지',
#  '코리아IT아카데미 신송하',
#  '11번가 파이썬',
#  'EZEN-빅데이터관련연수사업',
#  'IT뱅크 Python 이원우',
#  'SBS아카데미게임학원 김주평',
#  '펀코딩스쿨 방과후 코딩교육',
#  '파이썬 IB96',
#  '데이터가 만드는 커다란차이 ',
#  '쇼핑프로 위메프로',
#  '예스24 파이썬',
#  '코딩 1:1 프리미엄 과외',
#  'SBS아카데미게임학원 고은송',
#  '메가스터디IT아카데미 조동민',
#  '직무 교육 수업, 클래스유!',
#  'RPA 강의는 KS아카데미!',
#  '메가스터디IT아카데미 조충성',
#  'PC 모바일 컴퓨터교육 컴띵',
#  '파이썬 컴스쿨닷컴',
#  'SBS아카데미컴퓨터학원이진표',
#  'SBS컴퓨터아카데미학원김장현',
#  'SBS컴퓨터아카데미학원이성규',
#  'SBS아카데미컴퓨터학원정훈기',
#  '크리에이터링크 파이썬',
#  '아이티뱅크 신규상담 김지호',
#  '와이즈코딩러닝센터안양점',
#  '성인전문진로적성 아이엠컨설팅',
#  '카이스트 출신 화상코딩교육',
#  'IT뱅크 Python 김재헌',
#  'SBS아카데미컴퓨터학원김응천',
#  'SBS아카데미컴퓨터아트조준호',
#  '코리아IT아카데미 김선생',
#  '코딩공부하기전에 월화수목금퇼',
#  '코리아IT아카데미 윤예은',
#  '코리아IT아카데미 류재욱',
#  '코리아IT아카데미 이예림',
#  '글로벌 IT 인재개발원',
#  '생각하는코딩 파이씨코딩수학',
#  '마이로봇&코딩 교육원',
#  'KG아이티뱅크 하미나',
#  '코딩랩파이썬',
#  '돌고넷',
#  '용인종로컴퓨터학원',
#  '코리아IT아카데미 박이화',
#  'SBS아카데미컴퓨터학원유경민',
#  '로봇전문 SST',
#  '코리아 IT아카데미 조수정',
#  '파이썬 에어클래스',
#  '아두이노 공식대리점 엘레파츠',
#  '파이썬 집에서 편하게 따즈아',
#  '한국산업기술협회',
#  '등촌역 파이썬학원',
#  '에듀서치IT국비지원/취업지원',
#  '프로그래밍 패키지 인터넷강의',
#  'F-Lab&Company',
#  '에이블맥스(주) 파이썬',
#  '파이썬는 한컴아카데미',
#  '코리아IT아카데미 안민혁',
#  'KG아이티뱅크상담문의 전수민',
#  'ITBANK 교육문의 최윤석',
#  '코딩하는아이들(은평본원)',
#  '코리아IT강남 서동규 멘토',
#  'SBS아카데미컴퓨터학원표다운',
#  '코딩전문 교육기관 전성민',
#  '서울게임아카데미 프로그래밍',
#  '웹프로그래밍 강의, BOOT',
#  '파이썬강의 영우글로벌러닝',
#  '코리아IT아카데미 조재우',
#  '딥러닝 전문 아이디시스템',
#  '광교 플레이코딩학원',
#  '코리아IT아카데미 장재혁']

# %% [markdown]
# #### selenium
# - conda install -c conda-forge selenium
# - find_element_by_XXXX()
# - find_elements_by_XXXX()
# - _css_selector , _tag_name , _name , _id , _class_name
#
# #### DOM 내부에 있는 여러개의 요소들 중에서 처음 찾아지는 요소를 추출하는 메소드
#
#
# - find_element_by_id(id) # id 속성으로 요소를 하나 추출한다.
# - find_element_by_name(name) # name속성으로 요소를 하나 추출한다.
# - find_element_by_css_selector(query) # CSS 선택자로 요소를 하나 추출한다.
# - find_element_by_xpath(query) # XPath를 지정해 요소를 하나 추출한다.
# - find_element_by_tag_name(name) # 태그 이름이 name에 해당하는 요소를 하나 추출한다.
# - find_element_by_link_text(text) # 링크 텍스트로 요소를 하나 추출한다.
# - find_element_by_partial_link_text(text) # 링크의 자식요소에 포함돼 있는 텍스트로 요소를 하나 추출한다.
# - find_element_by_class_name(name) # 클래스 이름이 name에 해당하는 요소를 하나 추출한다.
#
# #### DOM 내부에 있는 여러개의 요소들을 모두 추출하는 메소드
# - find_elements_by_css_selector(query)
# - find_elements_by_xpath(query)
# - find_elements_by_tag_name(name)
# - find_elements_by_class_name(name)
# - find_elements_by_partial_link_text(text)
#
# #### DOM 요소에 적용할 수 있는 메소드
#
# - clear() # 글자를 입력할 수 있는 요소의 글자를 지운다.
# - click() # 요소를 클릭한다.
# - get_attribute(name) # 요소의 속성 중에 name에 해당되는 속성의 값을 추출한다.
# - is_displayed() # 요소가 화면에 출력되는지 확인한다.
# - is_enabled() # 요소가 활성화 되었는지 확인한다.
# - is_selected() # 체크박스 등의 요소가 선택 상태인지 확인한다.
# - screenshot(filename) # 화면을 캡처해서 filename으로 저장한다.
# - send_keys(value) # 키를 입력한다. 일반적으로 text 데이터를 보낸다. (그러면 특수키는? 아래 참고.)
# - submit() # 입력 양식을 전송한다.
# - value_of_css_property(name) # name에 해당하는 CSS 속성 값을 추출한다.

# %%
from selenium import webdriver

# %%
path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://python.org')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11932/3847100670.py in <module>
#       1 path = './driver/chromedriver.exe'
# ----> 2 driver = webdriver.Chrome(path)
#       3 driver.get('https://python.org')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      88
#      89         self.service = service
# ---> 90         self.service.start()
#      91
#      92         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home

# %%
li_tags = driver.find_elements_by_css_selector('#top .meta-navigation ul.menu li')
for li in li_tags : 
    print(li.text)
    print()

# %% [markdown]
# - https://datalab.naver.com/shoppingInsight/sCategory.naver
# - 클릭 제어

# %%
path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

# %%
li_tags = driver.find_elements_by_css_selector('.rank_top1000_list li')
li_tags

for li in li_tags : 
    print(li.text.split('\n'))
    print('*' * 50)

# %%
next_btn = driver.find_element_by_css_selector('a.btn_page_next')
next_btn.click()

# %%
# next_btn.is_enabled()

# %% [markdown]
# - 1 ~ 25 까지의 내용을 추출 [실습]

# %%
driver = webdriver.Chrome(path)
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

# %%
next_btn = driver.find_element_by_css_selector('a.btn_page_next')

item_lst = []


for idx in range(1, 26) :
    li_tags = driver.find_elements_by_css_selector('.rank_top1000_list li')
    
#     for li in li_tags : 
#         print(li.text.split('\n'))

    tmp_lst = [li.text.split('\n') for li in li_tags]
    item_lst.extend(tmp_lst)
    

    
    
    sleep(2)    
    next_btn.click()

# %%
item_lst

# %% [markdown]
# - https://www.ildong.com/kor/product/list.id?page=1&halt=&prdDisease=&prdCategory=&searchVal=&searchOption=0

# %%
driver = webdriver.Chrome(path)

# %%
driver.get('https://www.ildong.com/kor/product/list.id?page=1&halt=&prdDisease=&prdCategory=&searchVal=&searchOption=0')

list = driver.find_element_by_class_name('prList')
a_tags = list.find_elements_by_tag_name('a')
sleep(2)
a_tags[0].click()

detail = driver.find_element_by_class_name('detailCnt2')
detail.text

sleep(2)

driver.back()

# %%
for page in range(1,3) :
    print('page - ' , page)
    driver.get('https://www.ildong.com/kor/product/list.id?page='+str(page)+'&halt=&prdDisease=&prdCategory=&searchVal=&searchOption=0')
    sleep(3)
    
    list = driver.find_element_by_class_name('prList') # <div class='prlist' > 
    a_tags = list.find_elements_by_tag_name('a')

    # print( len(a_tags) )
    for idx in range(len(a_tags)) :
        
        print( a_tags[idx].find_element_by_tag_name('img').get_attribute('src') )
        img_jpg.append( a_tags[idx].find_element_by_tag_name('img').get_attribute('src') )

        
        a_tags[idx].click()
        detail = driver.find_element_by_class_name('detailCnt2')
        print( detail.text )
        print('*' * 100) 
        sleep(2)
        
        driver.back()
        
        list = driver.find_element_by_class_name('prList')
        a_tags = list.find_elements_by_tag_name('a')

# %%
import os

img_folder = './scraping_img'

if not os.path.isdir(img_folder) :
    os.mkdir(img_folder)

for index , link in enumerate(img_jpg) :
    print(index , '-' , link)
    urlretrieve(link , f'./scraping_img/{index}.jpg')

# %% [markdown]
# - 이미지 로컬 저장소에 저장하기

# %%
driver.get('https://search.daum.net/search?w=img&nil_search=btn&DA=NTB&enc=utf8&q=%EA%B0%95%EC%95%84%EC%A7%80')

imgs = driver.find_elements_by_css_selector('#imgList > div > a > img')
img_url = []

for img in imgs :
    url = img.get_attribute('src') 
    img_url.append(url)

# %%
img_url

# %%
import os

img_folder = './scraping_img'

if not os.path.isdir(img_folder) :
    os.mkdir(img_folder)

for index , link in enumerate(img_url) :
    print(index , '-' , link)
    urlretrieve(link , f'./scraping_img/{index}.jpg')
