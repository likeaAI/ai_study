# %% [markdown]
# #### 학습목표
# - 크롤링이란?   Web 상에서 동적데이터를 수집하는 작업(프로그래밍으로 자동화 기능) - Selenium
# - 스크래핑이란? Web 상에서 정적데이터를 수집하는 작업 - BeautifulSoup
#
# - HTML 페이지를 가져와서 html/css 파싱 , 필요한 데이터를 추출하는 기법

# %%
import numpy  as np
import pandas as pd

# 시각화
import matplotlib.pyplot as plt 
# %matplotlib inline

import seaborn as sns

import json 

import warnings
warnings.filterwarnings(action='ignore')

from datetime import date, datetime, timedelta
from dateutil.parser import parse


# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 


# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False


# crawling
from bs4 import BeautifulSoup
from urllib.request import urlopen , urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

import requests 
import re

print('numpy version  - ' , np.__version__)
print('pandas version - ' , pd.__version__)
# Out:
# numpy version  -  1.20.3
# pandas version -  1.3.4

# %%
html = '''
<html>
    <head>
        <title>연습</title>
    </head>
    <body>
        <h1>섭섭이와 함께하는 즐거운 스크랩핑</h1>
        <p class = 'css'>웹페이지 데이터 추출</p>
        <p id = 'data' align = 'center'>크롤링을 이용한 데이터 수집은 불법입니다.</p>
    </body>
</html>
'''

# %%
soup = BeautifulSoup(html , "html.parser") 
type( soup )
# Out:
# bs4.BeautifulSoup

# %%
print('bs - find , findAll , find_all')
print('attr     - ' , soup.find('p').string )
print('function - ' , soup.find('p').get_text() )
# Out:
# bs - find , findAll , find_all
# attr     -  웹페이지 데이터 추출
# function -  웹페이지 데이터 추출

# %%
print('id 식별자로 접근 - ') 
soup.find('p' , id = 'data').get_text()
# Out:
# id 식별자로 접근 -
# '크롤링을 이용한 데이터 수집은 불법입니다.'

# %%
print('class 식별자로 접근 - ') 
soup.find('p' , class_ = 'css').get_text()
# Out:
# class 식별자로 접근 -
# '웹페이지 데이터 추출'

# %%
print('일반 속성을 이용한 접근 - ') 
soup.find('p' , attrs = {'align' : 'center'}).get_text()
# Out:
# 일반 속성을 이용한 접근 -
# '크롤링을 이용한 데이터 수집은 불법입니다.'

# %%
webpage = requests.get('https://www.daangn.com/hot_articles') 
# webpage.content
# webpage.text
soup = BeautifulSoup(webpage.content , "html.parser") 
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/hot_articles" rel="canonical"/>
# <title>당근마켓 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="description">
# <link href="당근마켓" rel="author"/>
# <meta content="https://www.daangn.com/hot_articles" property="og:url">
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" property="og:title">
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="1463621440622064" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@danggeunmarket" name="twitter:site"/>
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" name="twitter:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="twitter:description"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" name="twitter:image"/>
# <meta content="d1f8112731c18313535732cf2516d6401bfed40a" name="naver-site-verification"/>
# <link href="/images/icons/shortcut_icon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://d1unjqcospf8gs.cloudfront.net/assets/home/articles/hot-f3ba94fbf724dbadb8e69c0792fe68666c0658dcf6bc77e9611339ad4532d606.css" media="all" rel="stylesheet"/>
# <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base-c64d203b6861097eddabc47f94aab7527c736b1d3be0f24c56e49dd3a9201622.js"></script>
# <link href="/images/icons/daangn_logo_192.png" rel="apple-touch-icon" sizes="192x192"/>
# <link href="/images/icons/daangn_logo_192.png" rel="apple-touch-icon-precomposed"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#   <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#   <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#   <![endif]-->
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="92nvsjvP8xm7mWrJaxkctS_-dhnlKskRGlsCDAfHpDEGKathx5WtvRT6jFdOhJ1GZVwmd1myVwQWQk_QsqtjGw" name="csrf-token"/>
# <script>
#     window.fbAsyncInit = function() {
#       FB.init({
#         appId      : '1463621440622064',
#         xfbml      : true,
#         version    : 'v2.4'
#       });
#     };
#
#     (function(d, s, id){
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) {return;}
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js";
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#   </script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#               (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-64551386-2', 'auto');
#      ga('set', 'dimension2', 'false');  ga('send', 'pageview'); </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#             n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#       n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '992961397411651');
#     facebookClickEvent("PageView")
#
#     function facebookClickEvent(eventName, data) {
#       if (data !== undefined) {
#           fbq('track', eventName, data)
#       } else {
#           fbq('track', eventName)
#       }
#     }
#
#     function facebookClickEventWithPageMove(eventName, data, targetUrl) {
#         facebookClickEvent(eventName, data);
#         window.location.href = targetUrl;
#     }
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=992961397411651&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-PJSK4QL');</script>
# <!-- End Google Tag Manager -->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "당근마켓",
#   "url": "https://www.daangn.com",
#   "sameAs": [
#     "https://www.facebook.com/daangn",
#     "https://blog.naver.com/daangn",
#     "https://www.youtube.com/channel/UC8tsBsQBuF7QybxgLmStihA",
#     "https://twitter.com/daangnmarket",
#     "https://www.instagram.com/daangnmarket",
#     "https://apps.apple.com/kr/app/id1018769995",
#     "https://play.google.com/store/apps/details?id=com.towneers.www"
#   ],
#   "logo": "https://www.daangn.com/logo.png"
# }
# </script>
# </link></meta></meta></meta></head>
# <body class="hoian-kr">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJSK4QL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Appsflyer Smart Banner -->
# <script>
#     !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "629f6f7a-a2a6-49c0-8d27-ffa48df1cd0e"}})
#     AF('banners', 'showBanner')
# </script>
# <!-- End Appsflyer Smart Banner-->
# <header id="fixed-bar">
# <div id="fixed-bar-wrap">
# <a href="https://www.daangn.com/" id="fixed-bar-logo-title">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" height="34" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-24b18257ac4ef693c02233bf21e9cb7ecbf43ebd8d5b40c24d99e14094a44c81.svg" width="120"/>
# </a>
# <section id="fixed-bar-search">
# <div class="search-input-wrap">
# <span class="sr-only">검색</span>
# <input class="fixed-search-input" id="header-search-input" name="header-search-input" placeholder="동네 이름, 물품명 등을 검색해보세요!" type="text"/>
# <button id="header-search-button">
# <img alt="Search" class="fixed-search-icon" height="24" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/search-icon-7008edd4f9aaa32188f55e65258f1c1905d7a9d1a3ca2a07ae809b5535380f14.svg" width="24"/>
# </button>
# </div>
# </section>
# <section class="fixed-bar-menu">
# <div class="fixed-download-wrapper">
# <input class="fixed-checkbox" id="fixed-menu-checkbox" type="checkbox"/>
# <label class="fixed-label" for="fixed-menu-checkbox">
#           다운로드
#           <svg class="menu-icon-svg" fill="none" height="7" viewbox="0 0 12 7" width="12" xmlns="http://www.w3.org/2000/svg">
# <path d="M1 1L6 6L11 1" stroke="#4D5159" strokelinecap="round" strokelinejoin="round" strokewidth="1.5"></path>
# </svg>
# </label>
# <ul class="fixed-menu-ul">
# <li>
# <a class="menu-anchor" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" height="18" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg" width="15"/>
# <span>App Store</span>
# </a> </li>
# <li>
# <a class="menu-anchor" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" height="18" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg" width="15"/>
# <span>Google Play</span>
# </a> </li>
# </ul>
# </div>
# <a href="https://chat.daangn.com" target="_blank">
# <button class="chat-button">
# <span class="button-text">당근채팅</span>
# <span class="button-beta">Beta</span>
# </button>
# </a>
# </section>
# </div>
# </header>
# <section id="content">
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# <nav id="hot-articles-navigation">
# <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value, false)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value, false)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# </nav>
# <section class="cards-wrap">
# <article class="card-top">
# <a class="card-link" data-event-label="386137030" href="/articles/386137030">
# <div class="card-photo">
# <img alt="디월트 20v  5ah배터리" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3de72d189e125a2e6c2f275ebfb104625a05cef22d5f0046b7cdb2f0769333e8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">디월트 20v  5ah배터리</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 금천구 가산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 38
#           </span>
#         ∙
#         <span>
#             채팅 114
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386958761" href="/articles/386958761">
# <div class="card-photo">
# <img alt="카페 정리합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/01D89E53778975D345EF5CAF84CDDD31BD87FF2BDD41CF04754AD479B62F561B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">카페 정리합니다</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         제주 제주시 한림읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387244905" href="/articles/387244905">
# <div class="card-photo">
# <img alt="선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/98866467024B867D5A1C9469B0F6889D8A851276E48BB1D48A243AE0FDFCB233.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선반</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경남 거제시 아주동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385626897" href="/articles/385626897">
# <div class="card-photo">
# <img alt="포켓몬 빵 팔아요." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/02d7d82c4b90113c6abc51b34700b95ff9201e04e60218f0dba0f46354f5d2dc.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬 빵 팔아요.</h2>
# <div class="card-price">
#         3,000원
#       </div>
# <div class="card-region-name">
#         경북 경주시 선도동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 69
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387320333" href="/articles/387320333">
# <div class="card-photo">
# <img alt="자전거판매해요 / 엘파마(ELFAMA)로사 R370 MTB(입문용모델)." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/c52a3d1f8ff11cca50b1724dd49d6b40e0dd43f7de403866ddd472629f03f03b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거판매해요 / 엘파마(ELFAMA)로사 R370 MTB(입문용모델).</h2>
# <div class="card-price">
#         80,000원
#       </div>
# <div class="card-region-name">
#         서울 강동구 암사제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 7
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387581344" href="/articles/387581344">
# <div class="card-photo">
# <img alt="위닉스뽀송 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/4A3208B3880CE8603DE6BD90E9A06C505B9B7E4B19CED948A20CB722D8670D5C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스뽀송 제습기</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 양정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386956636" href="/articles/386956636">
# <div class="card-photo">
# <img alt="포켓몬빵 사실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/36352DDB2461AC6CA22036DC15A64AF17DCDF6558C9F47946F77BD1CA8219365.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 사실분</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         전남 영암군 삼호읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 27
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387347483" href="/articles/387347483">
# <div class="card-photo">
# <img alt="⭐포.켓.몬.빵⭐포켓몬 ! 띠부띠부 !" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/45c15b1f219fbb4d61d0cb7a5526f10f1692a857773129a716d7e6338bb57dd3.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">⭐포.켓.몬.빵⭐포켓몬 ! 띠부띠부 !</h2>
# <div class="card-price">
#         1,500원
#       </div>
# <div class="card-region-name">
#         광주 남구 주월동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 25
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387071055" href="/articles/387071055">
# <div class="card-photo">
# <img alt="50인치TV 싸게 팔아요!! 급처!!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/2C5A259FB944BB20B2C94C2F8D6EECCDF4CCC7E97ECADA991E2919F4AE93CAA0.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">50인치TV 싸게 팔아요!! 급처!!</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경남 김해시 내외동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385411650" href="/articles/385411650">
# <div class="card-photo">
# <img alt="제습기 가져가실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/26e0d340c61d1f7da43a60b0ecc7fdeab8077d159823ee095a0deef1c7dede89.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기 가져가실분</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         인천 서구 가좌동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385970624" href="/articles/385970624">
# <div class="card-photo">
# <img alt="4단 서랍장 이사로 급매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/f8ca0c4a8b545e46f58adb241b4f2f3d663583b21d9e64fc57d3978ab17e2d83.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">4단 서랍장 이사로 급매합니다.</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387614277" href="/articles/387614277">
# <div class="card-photo">
# <img alt="이케아 나무선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/819318659A8DDA5E1FC169868D35E97551093D53EB09C6BA388F2655A428300C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이케아 나무선반</h2>
# <div class="card-price">
#         나눔
#       </div>
# <div class="card-region-name">
#         충남 홍성군 홍성읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387507786" href="/articles/387507786">
# <div class="card-photo">
# <img alt="창고정리♥디월트 드릴 만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ced6e691d5ff66da6a33e12860f0294c5e03b07f70d0534ca90d98a333b6a503.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">창고정리♥디월트 드릴 만원</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 일도2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384215721" href="/articles/384215721">
# <div class="card-photo">
# <img alt="라탄의자 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/8A7B89DD3720B2042F53F085A209C2A77013A970192A6F4F3D15651E7CABAEC4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">라탄의자 판매</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 아라이동
#       </div>
# <div class="card-counts">
# <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384171631" href="/articles/384171631">
# <div class="card-photo">
# <img alt="농업용3톤 물탱크 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1f1655027df5801241d3df37526c7ee29f69dad9598194758c9af455e48c91a6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">농업용3톤 물탱크 판매합니다</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         충남 서산시 성연면
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 62
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387305026" href="/articles/387305026">
# <div class="card-photo">
# <img alt="삼성냉동고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/6cbeb8363a4caa3a25098d91abebfcdd82f4617281f67630876a69a2608b170b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성냉동고</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 해운대구 우제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385998800" href="/articles/385998800">
# <div class="card-photo">
# <img alt="버버리 미니 크로스백" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/d9dc3e611fd7c216f88ddda25a045e94448e1c4a983ccbb6dc66afd930140987.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">버버리 미니 크로스백</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 일산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 21
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384836243" href="/articles/384836243">
# <div class="card-photo">
# <img alt="냉장고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/81435612873065caa3a4948d6de904591133dd2948f32e94110e12bc94e2c49f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉장고</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         서울 구로구 온수동
#       </div>
# <div class="card-counts">
# <span>
#             관심 28
#           </span>
#         ∙
#         <span>
#             채팅 57
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384040807" href="/articles/384040807">
# <div class="card-photo">
# <img alt="전자기타 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ACF3DE8C0B8FA319263B411469116B4F5B0689EBA1B7D01EE83EF9C5E9B05B35.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전자기타 팝니다</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 부암동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387072883" href="/articles/387072883">
# <div class="card-photo">
# <img alt="아세아관리기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/139f3fb5321df100f5762d86a88b010047e897fb3448cf59004cbad327d92330.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아세아관리기</h2>
# <div class="card-price">
#         200,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387252649" href="/articles/387252649">
# <div class="card-photo">
# <img alt="Tv" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ceeee1f7c46740a8360846ce9078c4a1222e05fc501099d01765b97596c275a8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">Tv</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         전남 여수시 학동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386873103" href="/articles/386873103">
# <div class="card-photo">
# <img alt="포켓몬 빵 팝니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/920473f20e5a3c280b5c294d63ad16a473c2a767a42a8012bba0cbb815cbf45e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬 빵 팝니다.</h2>
# <div class="card-price">
#         1,500원
#       </div>
# <div class="card-region-name">
#         충남 홍성군 홍성읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387583722" href="/articles/387583722">
# <div class="card-photo">
# <img alt="에어컨" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/339cb3dffc29da3b709a4ac2fd285ce11dd106c45bc1c88ce73d92be15b6dd76.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">에어컨</h2>
# <div class="card-price">
#         400,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 22
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387260985" href="/articles/387260985">
# <div class="card-photo">
# <img alt="LG통돌이 세탁기, 캔디 건조기 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/a25e9b37f62fa189c47935118d234e569969bbefcdd3d5f148a9e496c162d1be.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG통돌이 세탁기, 캔디 건조기 판매합니다</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         세종시  아름동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385698761" href="/articles/385698761">
# <div class="card-photo">
# <img alt="좋은책어린이 저학년문고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/D777EF1EC84E8167E70BAFFA2F7EC7E0523EA8CD3787C18F6F731C23D50DBCB4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">좋은책어린이 저학년문고</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385122231" href="/articles/385122231">
# <div class="card-photo">
# <img alt="에어컨 철거해 가실 분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/01afb9a91bc28d3defc0bbca229ab93da37479a2df01191867f9c7de2e3b1c63.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">에어컨 철거해 가실 분</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         인천 부평구 삼산2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387585366" href="/articles/387585366">
# <div class="card-photo">
# <img alt="영암꿀고구마(한입)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/455cc481ee8c6f6a0ef29537b2b3b16fef589c0ec69520bd3066670c4050ff1c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">영암꿀고구마(한입)</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 애월읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387455778" href="/articles/387455778">
# <div class="card-photo">
# <img alt="갤럭시노트10 256G" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/E74349E083FED224DA65ADBCE96ED44E7942C7142234154A4783F1A0D75B317B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">갤럭시노트10 256G</h2>
# <div class="card-price">
#         170,000원
#       </div>
# <div class="card-region-name">
#         대구 수성구 범어동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387216472" href="/articles/387216472">
# <div class="card-photo">
# <img alt="자전거 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/da1a1534537ba9870ef25917ebfcbb6656a9af71e0eb9edf0f73aac1067430b8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 판매합니다.</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 죽전동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387288803" href="/articles/387288803">
# <div class="card-photo">
# <img alt="아이폰12프로 그레파이트 128g 배터리성능👍" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0ee20a556f9bc8fa12febf1cdd2361fd65542451596a889fb3dbff4004608d43.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰12프로 그레파이트 128g 배터리성능👍</h2>
# <div class="card-price">
#         500,000원
#       </div>
# <div class="card-region-name">
#         경남 김해시 삼문동
#       </div>
# <div class="card-counts">
# <span>
#             관심 26
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385967724" href="/articles/385967724">
# <div class="card-photo">
# <img alt="무료드림 전자렌지" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/912170FAB4CBD12C374262146F21870CBC8C5D2A12C0FD1451C3366599DBD557.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">무료드림 전자렌지</h2>
# <div class="card-price">
#         나눔
#       </div>
# <div class="card-region-name">
#         인천 연수구 송도3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386507460" href="/articles/386507460">
# <div class="card-photo">
# <img alt="파라솔" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/04C46E91C93739F135CCBE1AD6DB33D87B46DED1F0B6F8E331DB2631E98F395C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">파라솔</h2>
# <div class="card-price">
#         나눔
#       </div>
# <div class="card-region-name">
#         경기도 용인시 처인구 모현읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386957414" href="/articles/386957414">
# <div class="card-photo">
# <img alt="5단선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0531A767888549FAFF300A8D74D11770209B3B262113EC5C5E041AAE69C78DE9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">5단선반</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         경남 거제시 사등면
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387296545" href="/articles/387296545">
# <div class="card-photo">
# <img alt="포켓몬빵 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/13FBF775C4747BD28F2683E0A43FEF192C989C0C91F11D66CF6671E56E73C854.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 팝니다</h2>
# <div class="card-price">
#         2,000원
#       </div>
# <div class="card-region-name">
#         인천 연수구 송도2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387497061" href="/articles/387497061">
# <div class="card-photo">
# <img alt="포르쉐 푸쉬카" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3c1a70fe02b957fe683d65a51b76e1b0fbfb4f5cbb12efa4edddec8fb143c1cf.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포르쉐 푸쉬카</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         세종시  보람동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387302376" href="/articles/387302376">
# <div class="card-photo">
# <img alt="내친구 과학공룡 전집 53권" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/16bad93d0a4d4856cd701fbb4bb1e3da70dbd1069b11b2a403ca6c1e96c718e4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">내친구 과학공룡 전집 53권</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         울산 울주군 범서읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385884940" href="/articles/385884940">
# <div class="card-photo">
# <img alt="구글 크롬캐스트4" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/44a77e1192f69ca9137691a87f8e81df0d19a70b11ea0b7d90a7087b0eb54ff5.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">구글 크롬캐스트4</h2>
# <div class="card-price">
#         43,000원
#       </div>
# <div class="card-region-name">
#         서울 강남구 청담동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387291380" href="/articles/387291380">
# <div class="card-photo">
# <img alt="투인원 휘센 에어컨, LG세탁기 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1317aed9aabc2a6969bc04c583128d33e520aa291067e47ed19e3526bbb2ce1c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">투인원 휘센 에어컨, LG세탁기 팔아요</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         충북 청주시 서원구 사직2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386710399" href="/articles/386710399">
# <div class="card-photo">
# <img alt="스테인레스제 칼세트" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3df554167367c08e314ffab6267e4b11db0f37105336bc5178ab2234129deb4a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스테인레스제 칼세트</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 공릉동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387364744" href="/articles/387364744">
# <div class="card-photo">
# <img alt="포켓몬빵 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/66daef3f24429621db5b3ef891a353b0ee8822512ed9b59cddd6f8970a4ce50f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 팝니다</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         전북 전주시 완산구 효자동3가
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387352659" href="/articles/387352659">
# <div class="card-photo">
# <img alt="산드로 가디건" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/cbdabdd5307cf1a9ad63e9c7476fd7ccee4b3f9c2ead765868a53ce1421f032d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">산드로 가디건</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384443781" href="/articles/384443781">
# <div class="card-photo">
# <img alt="접이식 자전거 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/cf4d631bc8f61ce5ba50db4f9d74aec8008081519165b10bfeb6c51601c16694.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">접이식 자전거 팝니다</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         충북 청주시 흥덕구 가경동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387387006" href="/articles/387387006">
# <div class="card-photo">
# <img alt="스팸 좋아하시는분!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/972862A36542FE083A6AF3A1FEC3BA7093639A239B1E7F5BC1A7E7D2FA03883C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸 좋아하시는분!</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경북 포항시 북구 두호동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387337542" href="/articles/387337542">
# <div class="card-photo">
# <img alt="포켓몬빵 ‘정가’ 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/DBC48232A422F05B919DC0BA4C96D7858149A91A63708A3E09441813C82D3593.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 ‘정가’ 판매합니다</h2>
# <div class="card-price">
#         1,500원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 30
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384027432" href="/articles/384027432">
# <div class="card-photo">
# <img alt="LG 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/a5566f334e3af810b3b2818f0b76725911cbedaf75e755217d468e60a7eb989e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG 제습기</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 강북구 미아동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386340786" href="/articles/386340786">
# <div class="card-photo">
# <img alt="토마토 농장 입니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/82bab9855e741f00994bd55ba5e7df23404f9002e6d114192f7a2f42aa96779b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">토마토 농장 입니다</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경북 상주시 공검면
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 37
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387076548" href="/articles/387076548">
# <div class="card-photo">
# <img alt="다들 너무 비싸게 파시는거 같아서 2000원에 팝니다 5000원으로 파시는거는 좀 아닌거 같아용!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1F7B7E99A973E777C07AC471FEA12243A88F8012603F78E0447279E7DAF036A2.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">다들 너무 비싸게 파시는거 같아서 2000원에 팝니다 5000원으로 파시는거는 좀 아닌거 같아용!</h2>
# <div class="card-price">
#         2,000원
#       </div>
# <div class="card-region-name">
#         전남 광양시 중마동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387329601" href="/articles/387329601">
# <div class="card-photo">
# <img alt="모에스던 쇼파" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/BC6B5E59C7ED3A91CC1BC8BFDE37B50E53BA2B1849DBA8A732F1293A4263C55B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">모에스던 쇼파</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         대구 북구 칠성동
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386370495" href="/articles/386370495">
# <div class="card-photo">
# <img alt="삼성 제습기 만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0e697e264a354c73cfd4df58a9fb658ce4a1dc61203e3560b27635b0771ac405.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성 제습기 만원</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         서울 동작구 대방동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387353200" href="/articles/387353200">
# <div class="card-photo">
# <img alt="루이비통 다미에 에바클러치 가방 팔아용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/08D0A3F9D566372D078C265D34B01223851171AD069982F53267659FA05D654E.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">루이비통 다미에 에바클러치 가방 팔아용</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경기도 수원시 권선구 권선동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386621334" href="/articles/386621334">
# <div class="card-photo">
# <img alt="포켓몬빵팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/81d24b2ccf0b3a14092fbd73278044927e4139061f0b1a76384d2c3c61c08321.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵팔아요</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         전북 익산시 평화동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 50
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387571039" href="/articles/387571039">
# <div class="card-photo">
# <img alt="아우디 푸쉬카팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/6ffbd08b03adb6fe63ba0557532b87b2c58fcdeb018c5bb793d2ed908b3a0ed6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아우디 푸쉬카팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경북 포항시 남구 효곡동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387329426" href="/articles/387329426">
# <div class="card-photo">
# <img alt="LED 커브드 TV겸 모니터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/116166f3eb366cf62434ce58d526e5454d73bf054bc23132c7cd09c3ccae336f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LED 커브드 TV겸 모니터</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 향남읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 24
#           </span>
#         ∙
#         <span>
#             채팅 29
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387253711" href="/articles/387253711">
# <div class="card-photo">
# <img alt="다이슨 공기청정기&amp;선풍기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3b80b1321aa78290191e8bd01c5886b80612d12a73222e973740623f6d0ac6d5.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">다이슨 공기청정기&amp;선풍기</h2>
# <div class="card-price">
#         90,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 고촌읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385962331" href="/articles/385962331">
# <div class="card-photo">
# <img alt="세탁기 무료로 가져 가실분.." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/263adfbfd98671946e58584c86eb17e6aef3ecdbb5ee0f7ccbe6ee03b1d11560.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">세탁기 무료로 가져 가실분..</h2>
# <div class="card-price">
#         10원
#       </div>
# <div class="card-region-name">
#         경북 경산시 하양읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387114344" href="/articles/387114344">
# <div class="card-photo">
# <img alt="뮤츠 띠부띠부씰 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/9a4caecfbbfacfc0e18c6d616aa9ade3a82451c744bcd8001c625c1f3ee20de7.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">뮤츠 띠부띠부씰 팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
# ...
#         160,000원
#       </div>
# <div class="card-region-name">
#         서울 금천구 가산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387179584" href="/articles/387179584">
# <div class="card-photo">
# <img alt="삼천리 mtb27단 자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/60ab6a30ce084e10f8c4a683f17f629b323fbe98cca73366f164382b842b237a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼천리 mtb27단 자전거</h2>
# <div class="card-price">
#         40,000원
#       </div>
# <div class="card-region-name">
#         서울 서대문구 홍은제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384861710" href="/articles/384861710">
# <div class="card-photo">
# <img alt="네스프레소 버츄오 캡슐" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/7E8D37FB2C3D382DA8221BBD8BDE32BA5B412A7BE9DBB25832DF09FA89EF1513.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">네스프레소 버츄오 캡슐</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 해운대구 우동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387004111" href="/articles/387004111">
# <div class="card-photo">
# <img alt="[책장정리]책 팝니다(공룡유치원,이야기솜사탕,한반도와세기의공룡들 외)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/766b505d15e1092ce7555485f40891f5db2a941ace047d8f70dd814702a23576.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">[책장정리]책 팝니다(공룡유치원,이야기솜사탕,한반도와세기의공룡들 외)</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         울산 울주군 범서읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385045307" href="/articles/385045307">
# <div class="card-photo">
# <img alt="18k급처분사정상" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/5c4d16285e02a83cecef7cad975ec0a3fee9846a61cab8af215aeb4f529f3d56.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">18k급처분사정상</h2>
# <div class="card-price">
#         900,000원
#       </div>
# <div class="card-region-name">
#         경북 칠곡군 석적읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387000029" href="/articles/387000029">
# <div class="card-photo">
# <img alt="포켓몬빵 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/671F6588C2FE389090D682E58893ADAD1D3488F665B68B76C486053EC045D6B9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 팝니다</h2>
# <div class="card-price">
#         100원
#       </div>
# <div class="card-region-name">
#         대구 달성군 다사읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 30
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384897639" href="/articles/384897639">
# <div class="card-photo">
# <img alt="컨테이너 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/25f9a6685479fcd78040a6087012c2067578ee8a00c88321c908dd62b8b16be1.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컨테이너 팝니다</h2>
# <div class="card-price">
#         1,500,000원
#       </div>
# <div class="card-region-name">
#         광주 서구 금호2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 39
#           </span>
#         ∙
#         <span>
#             채팅 43
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386570215" href="/articles/386570215">
# <div class="card-photo">
# <img alt="삼성냉장고 255리터 완전깨끗" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/a0a14d14272a38cc47be0e8d84eae3a1efdc6c8ea521ab670699881dbac71437.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성냉장고 255리터 완전깨끗</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 덕양구 향동동
#       </div>
# <div class="card-counts">
# <span>
#             관심 29
#           </span>
#         ∙
#         <span>
#             채팅 26
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385979024" href="/articles/385979024">
# <div class="card-photo">
# <img alt="의자 팝니다(무료)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/83eb2187409d1164826748d756dfa00ce819a0883499c81583351d1276fd5a17.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">의자 팝니다(무료)</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         충남 논산시 내동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 44
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385307060" href="/articles/385307060">
# <div class="card-photo">
# <img alt="포켓몬빵 빨리 팔아용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/277BB395134C3D535FA7BA08CD299C865E15606DDDB1E0B703F802FE3772413F.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 빨리 팔아용</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         서울 강북구 번동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 50
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386983173" href="/articles/386983173">
# <div class="card-photo">
# <img alt="아이패드 프로 11인치 3세대(5세대)최신형 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/280a0f6e1428d75bc072a37b218f941e729d0e8ed99eb1eff97b0427a2aad158.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이패드 프로 11인치 3세대(5세대)최신형 판매합니다</h2>
# <div class="card-price">
#         750,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 고촌읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 23
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387008952" href="/articles/387008952">
# <div class="card-photo">
# <img alt="마끼다 송풍기, 무선샌딩기 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1196c495fcae2658c3fa8c280e857c2cf4b7b9b51ac6943920c4b040f3f813f4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">마끼다 송풍기, 무선샌딩기 판매합니다.</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387310274" href="/articles/387310274">
# <div class="card-photo">
# <img alt="위닉스 제습기 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/9eee7f2c5c069e2400d232dff9ddfd53936293100b9b6561deeece55e08c419c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 제습기 팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 방배동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386470994" href="/articles/386470994">
# <div class="card-photo">
# <img alt="바테이블, 바의자 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ca4ae037ffdfb26c9a9cf42454cb0be5cc871e2a1860e9b1d57b103342c09497.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">바테이블, 바의자 판매</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         강원도 동해시 구미동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386868741" href="/articles/386868741">
# <div class="card-photo">
# <img alt="쌀 20kg+ 드림" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/F602EB2D08514B63E8A37D8BED5C1104F9AF0914D69D1F20E3E944F3DFB01670.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">쌀 20kg+ 드림</h2>
# <div class="card-price">
#         1,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 논현동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387211344" href="/articles/387211344">
# <div class="card-photo">
# <img alt="컴퓨터 부품용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/40B01FCD1F0C61B8C44B04B18F03D969544942A247B1CF9CB791292FD309B92C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컴퓨터 부품용</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 서대문구 연희동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# </section>
# <section id="hot-articles-go-download">
# <h3>
#         더 구경하고 싶나요?
#     </h3>
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# <div id="hot-articles-download-buttons">
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a> <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a> </div>
# </section>
# </section>
# <script charset="utf-8" type="text/javascript">
#   function changeRegion(key, value, is_group_article_page){
#     var url_array
#     if(window.location.pathname === "/hot_articles" && window.location.href.match(/\?/)) {
#       url_array = window.location.href.split('?')[1].split(/(?:r1|&?r2)=/)
#       url_array.unshift("")
#     } else {
#       url_array = window.location.pathname.split('/')
#       if(is_group_article_page) {
#           url_array.splice(1,2) // remove 'group_articles/:gid'
#       }
#     }
#     var keys = { r1: 2, r2: 3, r3: 4 }
#     url_array[keys[key]] = value
#     url_array[1] = 'region'
#       if(key == 'r2' && decodeURI(url_array[2]) == "세종특별자치시") {
#         url_array[4] = value
#         url_array[3] = "_"
#       }
#     if(key == 'r1') { url_array.splice(3, 2) }
#     if(key == 'r2' && url_array[3] !== "_") { url_array.splice(4, 1) }
#     if(is_group_article_page) {
#         window.location.href = window.location.origin + window.location.pathname.split('/').slice(0,3).concat(url_array.slice(1)).join('/')
#     } else {
#         window.location.href = window.location.origin + url_array.join('/')
#     }
#   }
# </script>
# <footer id="footer">
# <div class="footer-container">
# <div class="footer-top">
# <div class="footer-logo"></div>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="/trust">믿을 수 있는 중고거래</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="https://cs.kr.karrotmarket.com/wv/faqs">자주 묻는 질문</a></li>
# </ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="https://ads-local.daangn.com" target="_blank">광고주센터</a></li>
# <li class="footer-list-item">
# <a href="https://daangnpay.com" target="_blank">당근페이</a>
# <li class="footer-list-item">
# <a class="ga-click" data-event-action="hot_articles" data-event-category="town_link_from" data-event-label="footer_town" href="https://town.daangn.com" target="_blank">동네가게</a>
# </li>
# </li></ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a href="https://team.daangn.com/" target="_blank">회사 소개</a></li>
# <li class="footer-list-item"><a href="https://team.daangn.com/jobs/" target="_blank">채용</a></li>
# </ul>
# <ul class="footer-list policy">
# <li class="footer-list-item"><a href="https://policy.daangn.com/terms.html" target="_blank">이용약관</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/privacy.html" target="_blank">개인정보처리방침</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/location.html" target="_blank">위치기반서비스 이용약관</a></li>
# </ul>
# </div>
# <div class="footer-bottom">
# <div id="copyright">
# <ul class="copyright-list">
# <li class="copyright-list-item">고객문의 <a href="mailto:cs@daangnservice.com">cs@daangnservice.com</a></li>
# <li class="copyright-list-item">제휴문의 <a href="mailto:contact@daangn.com">contact@daangn.com</a></li>
# </ul>
# <ul class="copyright-list">
# <li class="copyright-list-item">지역광고 <a href="mailto:ad@daangn.com">ad@daangn.com</a></li>
# <li class="copyright-list-item">PR문의 <a href="mailto:pr@daangn.com">pr@daangn.com</a></li>
# </ul>
# <ul class="copyright-list copyright-list-light">
# <li class="copyright-list-item"><address>서울특별시 구로구 디지털로30길 28, 609호 (당근서비스)</address></li>
# <li class="copyright-list-item">사업자 등록번호 : 375-87-00088</li>
# <li class="copyright-list-item">직업정보제공사업 신고번호 : J1200020200016</li>
# </ul>
# <div id="social">
# <ul class="social-list">
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.facebook.com/daangn" target="_blank">
# <img alt="facebook" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-facebook-0563f4a93852d073b41f13b8bcabb03d47af3bb3a6755cdfedd8a73686c7f18c.svg"/>
# <span class="sr-only">facebook</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.instagram.com/daangnmarket/" target="_blank">
# <img alt="instagram" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-instagram-2f6c88a461597907c114b7ce28eab053fcae791ed26417915fefb6f7c9f95756.svg"/>
# <span class="sr-only">instagram</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://blog.naver.com/daangn" target="_blank">
# <img alt="blog" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-blog-e1b0d512d1766a6962ec5bbb5b0803d2a6a9c55ad97db5ba9eebb76013caceba.svg"/>
# <span class="sr-only">blog</span>
# </a> </li>
# <li class="global-links">
# <img alt="country" height="24" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-global-2f53678b428ec623cefd07a90dd7777f3e55fc0433918f645d7d75ace6ff1fc3.png" width="24"/>
# <select id="global-links-select">
# <option value="kr">한국</option>
# <option value="https://uk.karrotmarket.com">영국</option>
# <option value="https://ca.karrotmarket.com">캐나다</option>
# <option value="https://us.karrotmarket.com">미국</option>
# <option value="https://jp.karrotmarket.com">일본</option>
# </select>
# </li>
# </ul>
# </div>
# <div class="copyright-text">©Danggeun Market Inc.</div>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %%
print('태그 탐색 - ') 
print('<p>    - ' , soup.p , soup.find('p'))
print('string - ' , soup.p.string)
# Out:
# 태그 탐색 -
# <p>    -  <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p> <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# string -  당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!

# %%
print('<h1>    - '  , soup.h1 , soup.find('h1'))
print('string  - '  , soup.h1.string)
for txt in soup.h1.children : 
    print(txt)
# Out:
# <h1>    -  <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1> <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# string  -
#
#
#       중고거래 인기매물
#
#
#
#
#       중고거래 인기매물

# %%
print('<ul>    - '  , soup.ul)
print()

for li in soup.ul.children : 
    print(li)
# Out:
# <ul>    -  <ul class="fixed-menu-ul">
# <li>
# <a class="menu-anchor" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" height="18" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg" width="15"/>
# <span>App Store</span>
# </a> </li>
# <li>
# <a class="menu-anchor" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" height="18" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg" width="15"/>
# <span>Google Play</span>
# </a> </li>
# </ul>
#
#
#
# <li>
# <a class="menu-anchor" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" id="header-download-button-ios" target="_blank">
# <img alt="App Store" height="18" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/apple-store-3a664174124650d63cae365bc55586fc5ff27b822b1b97788fc4af77d73d00c8.svg" width="15"/>
# <span>App Store</span>
# </a> </li>
#
#
# <li>
# <a class="menu-anchor" href="https://play.google.com/store/apps/details?id=com.towneers.www" id="header-download-button-android" target="_blank">
# <img alt="Google Play" height="18" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/google-play-c9ad0fc573cd01e2b982df5de6709a3d8d7cec8d9b58a5c08db7da0b92a32a75.svg" width="15"/>
# <span>Google Play</span>
# </a> </li>

# %%
for txt in soup.h1.parents : 
    print(txt)
# Out:
# <section id="content">
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# <nav id="hot-articles-navigation">
# <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value, false)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value, false)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# </nav>
# <section class="cards-wrap">
# <article class="card-top">
# <a class="card-link" data-event-label="386137030" href="/articles/386137030">
# <div class="card-photo">
# <img alt="디월트 20v  5ah배터리" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3de72d189e125a2e6c2f275ebfb104625a05cef22d5f0046b7cdb2f0769333e8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">디월트 20v  5ah배터리</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 금천구 가산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 38
#           </span>
#         ∙
#         <span>
#             채팅 114
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386958761" href="/articles/386958761">
# <div class="card-photo">
# <img alt="카페 정리합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/01D89E53778975D345EF5CAF84CDDD31BD87FF2BDD41CF04754AD479B62F561B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">카페 정리합니다</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         제주 제주시 한림읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387244905" href="/articles/387244905">
# <div class="card-photo">
# <img alt="선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/98866467024B867D5A1C9469B0F6889D8A851276E48BB1D48A243AE0FDFCB233.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선반</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경남 거제시 아주동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385626897" href="/articles/385626897">
# <div class="card-photo">
# <img alt="포켓몬 빵 팔아요." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/02d7d82c4b90113c6abc51b34700b95ff9201e04e60218f0dba0f46354f5d2dc.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬 빵 팔아요.</h2>
# <div class="card-price">
#         3,000원
#       </div>
# <div class="card-region-name">
#         경북 경주시 선도동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 69
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387320333" href="/articles/387320333">
# <div class="card-photo">
# <img alt="자전거판매해요 / 엘파마(ELFAMA)로사 R370 MTB(입문용모델)." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/c52a3d1f8ff11cca50b1724dd49d6b40e0dd43f7de403866ddd472629f03f03b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거판매해요 / 엘파마(ELFAMA)로사 R370 MTB(입문용모델).</h2>
# <div class="card-price">
#         80,000원
#       </div>
# <div class="card-region-name">
#         서울 강동구 암사제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 7
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387581344" href="/articles/387581344">
# <div class="card-photo">
# <img alt="위닉스뽀송 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/4A3208B3880CE8603DE6BD90E9A06C505B9B7E4B19CED948A20CB722D8670D5C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스뽀송 제습기</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 양정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386956636" href="/articles/386956636">
# <div class="card-photo">
# <img alt="포켓몬빵 사실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/36352DDB2461AC6CA22036DC15A64AF17DCDF6558C9F47946F77BD1CA8219365.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 사실분</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         전남 영암군 삼호읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 27
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387347483" href="/articles/387347483">
# <div class="card-photo">
# <img alt="⭐포.켓.몬.빵⭐포켓몬 ! 띠부띠부 !" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/45c15b1f219fbb4d61d0cb7a5526f10f1692a857773129a716d7e6338bb57dd3.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">⭐포.켓.몬.빵⭐포켓몬 ! 띠부띠부 !</h2>
# <div class="card-price">
#         1,500원
#       </div>
# <div class="card-region-name">
#         광주 남구 주월동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 25
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387071055" href="/articles/387071055">
# <div class="card-photo">
# <img alt="50인치TV 싸게 팔아요!! 급처!!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/2C5A259FB944BB20B2C94C2F8D6EECCDF4CCC7E97ECADA991E2919F4AE93CAA0.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">50인치TV 싸게 팔아요!! 급처!!</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경남 김해시 내외동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385411650" href="/articles/385411650">
# <div class="card-photo">
# <img alt="제습기 가져가실분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/26e0d340c61d1f7da43a60b0ecc7fdeab8077d159823ee095a0deef1c7dede89.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기 가져가실분</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         인천 서구 가좌동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385970624" href="/articles/385970624">
# <div class="card-photo">
# <img alt="4단 서랍장 이사로 급매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/f8ca0c4a8b545e46f58adb241b4f2f3d663583b21d9e64fc57d3978ab17e2d83.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">4단 서랍장 이사로 급매합니다.</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387614277" href="/articles/387614277">
# <div class="card-photo">
# <img alt="이케아 나무선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/819318659A8DDA5E1FC169868D35E97551093D53EB09C6BA388F2655A428300C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이케아 나무선반</h2>
# <div class="card-price">
#         나눔
#       </div>
# <div class="card-region-name">
#         충남 홍성군 홍성읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387507786" href="/articles/387507786">
# <div class="card-photo">
# <img alt="창고정리♥디월트 드릴 만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ced6e691d5ff66da6a33e12860f0294c5e03b07f70d0534ca90d98a333b6a503.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">창고정리♥디월트 드릴 만원</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 일도2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384215721" href="/articles/384215721">
# <div class="card-photo">
# <img alt="라탄의자 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/8A7B89DD3720B2042F53F085A209C2A77013A970192A6F4F3D15651E7CABAEC4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">라탄의자 판매</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 아라이동
#       </div>
# <div class="card-counts">
# <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384171631" href="/articles/384171631">
# <div class="card-photo">
# <img alt="농업용3톤 물탱크 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1f1655027df5801241d3df37526c7ee29f69dad9598194758c9af455e48c91a6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">농업용3톤 물탱크 판매합니다</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         충남 서산시 성연면
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 62
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387305026" href="/articles/387305026">
# <div class="card-photo">
# <img alt="삼성냉동고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/6cbeb8363a4caa3a25098d91abebfcdd82f4617281f67630876a69a2608b170b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성냉동고</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 해운대구 우제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385998800" href="/articles/385998800">
# <div class="card-photo">
# <img alt="버버리 미니 크로스백" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/d9dc3e611fd7c216f88ddda25a045e94448e1c4a983ccbb6dc66afd930140987.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">버버리 미니 크로스백</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 일산서구 일산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 21
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384836243" href="/articles/384836243">
# <div class="card-photo">
# <img alt="냉장고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/81435612873065caa3a4948d6de904591133dd2948f32e94110e12bc94e2c49f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">냉장고</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         서울 구로구 온수동
#       </div>
# <div class="card-counts">
# <span>
#             관심 28
#           </span>
#         ∙
#         <span>
#             채팅 57
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384040807" href="/articles/384040807">
# <div class="card-photo">
# <img alt="전자기타 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ACF3DE8C0B8FA319263B411469116B4F5B0689EBA1B7D01EE83EF9C5E9B05B35.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">전자기타 팝니다</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 부산진구 부암동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387072883" href="/articles/387072883">
# <div class="card-photo">
# <img alt="아세아관리기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/139f3fb5321df100f5762d86a88b010047e897fb3448cf59004cbad327d92330.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아세아관리기</h2>
# <div class="card-price">
#         200,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387252649" href="/articles/387252649">
# <div class="card-photo">
# <img alt="Tv" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ceeee1f7c46740a8360846ce9078c4a1222e05fc501099d01765b97596c275a8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">Tv</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         전남 여수시 학동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386873103" href="/articles/386873103">
# <div class="card-photo">
# <img alt="포켓몬 빵 팝니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/920473f20e5a3c280b5c294d63ad16a473c2a767a42a8012bba0cbb815cbf45e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬 빵 팝니다.</h2>
# <div class="card-price">
#         1,500원
#       </div>
# <div class="card-region-name">
#         충남 홍성군 홍성읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387583722" href="/articles/387583722">
# <div class="card-photo">
# <img alt="에어컨" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/339cb3dffc29da3b709a4ac2fd285ce11dd106c45bc1c88ce73d92be15b6dd76.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">에어컨</h2>
# <div class="card-price">
#         400,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 22
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387260985" href="/articles/387260985">
# <div class="card-photo">
# <img alt="LG통돌이 세탁기, 캔디 건조기 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/a25e9b37f62fa189c47935118d234e569969bbefcdd3d5f148a9e496c162d1be.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG통돌이 세탁기, 캔디 건조기 판매합니다</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         세종시  아름동
#       </div>
# <div class="card-counts">
# <span>
#             관심 17
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385698761" href="/articles/385698761">
# <div class="card-photo">
# <img alt="좋은책어린이 저학년문고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/D777EF1EC84E8167E70BAFFA2F7EC7E0523EA8CD3787C18F6F731C23D50DBCB4.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">좋은책어린이 저학년문고</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385122231" href="/articles/385122231">
# <div class="card-photo">
# <img alt="에어컨 철거해 가실 분" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/01afb9a91bc28d3defc0bbca229ab93da37479a2df01191867f9c7de2e3b1c63.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">에어컨 철거해 가실 분</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         인천 부평구 삼산2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387585366" href="/articles/387585366">
# <div class="card-photo">
# <img alt="영암꿀고구마(한입)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/455cc481ee8c6f6a0ef29537b2b3b16fef589c0ec69520bd3066670c4050ff1c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">영암꿀고구마(한입)</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 애월읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 20
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387455778" href="/articles/387455778">
# <div class="card-photo">
# <img alt="갤럭시노트10 256G" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/E74349E083FED224DA65ADBCE96ED44E7942C7142234154A4783F1A0D75B317B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">갤럭시노트10 256G</h2>
# <div class="card-price">
#         170,000원
#       </div>
# <div class="card-region-name">
#         대구 수성구 범어동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387216472" href="/articles/387216472">
# <div class="card-photo">
# <img alt="자전거 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/da1a1534537ba9870ef25917ebfcbb6656a9af71e0eb9edf0f73aac1067430b8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자전거 판매합니다.</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 용인시 수지구 죽전동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387288803" href="/articles/387288803">
# <div class="card-photo">
# <img alt="아이폰12프로 그레파이트 128g 배터리성능👍" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0ee20a556f9bc8fa12febf1cdd2361fd65542451596a889fb3dbff4004608d43.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰12프로 그레파이트 128g 배터리성능👍</h2>
# <div class="card-price">
#         500,000원
#       </div>
# <div class="card-region-name">
#         경남 김해시 삼문동
#       </div>
# <div class="card-counts">
# <span>
#             관심 26
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385967724" href="/articles/385967724">
# <div class="card-photo">
# <img alt="무료드림 전자렌지" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/912170FAB4CBD12C374262146F21870CBC8C5D2A12C0FD1451C3366599DBD557.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">무료드림 전자렌지</h2>
# <div class="card-price">
#         나눔
#       </div>
# <div class="card-region-name">
#         인천 연수구 송도3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386507460" href="/articles/386507460">
# <div class="card-photo">
# <img alt="파라솔" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/04C46E91C93739F135CCBE1AD6DB33D87B46DED1F0B6F8E331DB2631E98F395C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">파라솔</h2>
# <div class="card-price">
#         나눔
#       </div>
# <div class="card-region-name">
#         경기도 용인시 처인구 모현읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386957414" href="/articles/386957414">
# <div class="card-photo">
# <img alt="5단선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0531A767888549FAFF300A8D74D11770209B3B262113EC5C5E041AAE69C78DE9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">5단선반</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         경남 거제시 사등면
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 9
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387296545" href="/articles/387296545">
# <div class="card-photo">
# <img alt="포켓몬빵 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/13FBF775C4747BD28F2683E0A43FEF192C989C0C91F11D66CF6671E56E73C854.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 팝니다</h2>
# <div class="card-price">
#         2,000원
#       </div>
# <div class="card-region-name">
#         인천 연수구 송도2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387497061" href="/articles/387497061">
# <div class="card-photo">
# <img alt="포르쉐 푸쉬카" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3c1a70fe02b957fe683d65a51b76e1b0fbfb4f5cbb12efa4edddec8fb143c1cf.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포르쉐 푸쉬카</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         세종시  보람동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387302376" href="/articles/387302376">
# <div class="card-photo">
# <img alt="내친구 과학공룡 전집 53권" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/16bad93d0a4d4856cd701fbb4bb1e3da70dbd1069b11b2a403ca6c1e96c718e4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">내친구 과학공룡 전집 53권</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         울산 울주군 범서읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385884940" href="/articles/385884940">
# <div class="card-photo">
# <img alt="구글 크롬캐스트4" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/44a77e1192f69ca9137691a87f8e81df0d19a70b11ea0b7d90a7087b0eb54ff5.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">구글 크롬캐스트4</h2>
# <div class="card-price">
#         43,000원
#       </div>
# <div class="card-region-name">
#         서울 강남구 청담동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 32
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387291380" href="/articles/387291380">
# <div class="card-photo">
# <img alt="투인원 휘센 에어컨, LG세탁기 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1317aed9aabc2a6969bc04c583128d33e520aa291067e47ed19e3526bbb2ce1c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">투인원 휘센 에어컨, LG세탁기 팔아요</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         충북 청주시 서원구 사직2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386710399" href="/articles/386710399">
# <div class="card-photo">
# <img alt="스테인레스제 칼세트" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3df554167367c08e314ffab6267e4b11db0f37105336bc5178ab2234129deb4a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스테인레스제 칼세트</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         서울 노원구 공릉동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387364744" href="/articles/387364744">
# <div class="card-photo">
# <img alt="포켓몬빵 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/66daef3f24429621db5b3ef891a353b0ee8822512ed9b59cddd6f8970a4ce50f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 팝니다</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         전북 전주시 완산구 효자동3가
#       </div>
# <div class="card-counts">
# <span>
#             관심 0
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387352659" href="/articles/387352659">
# <div class="card-photo">
# <img alt="산드로 가디건" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/cbdabdd5307cf1a9ad63e9c7476fd7ccee4b3f9c2ead765868a53ce1421f032d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">산드로 가디건</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 16
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384443781" href="/articles/384443781">
# <div class="card-photo">
# <img alt="접이식 자전거 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/cf4d631bc8f61ce5ba50db4f9d74aec8008081519165b10bfeb6c51601c16694.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">접이식 자전거 팝니다</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         충북 청주시 흥덕구 가경동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387387006" href="/articles/387387006">
# <div class="card-photo">
# <img alt="스팸 좋아하시는분!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/972862A36542FE083A6AF3A1FEC3BA7093639A239B1E7F5BC1A7E7D2FA03883C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">스팸 좋아하시는분!</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경북 포항시 북구 두호동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387337542" href="/articles/387337542">
# <div class="card-photo">
# <img alt="포켓몬빵 ‘정가’ 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/DBC48232A422F05B919DC0BA4C96D7858149A91A63708A3E09441813C82D3593.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 ‘정가’ 판매합니다</h2>
# <div class="card-price">
#         1,500원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 30
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384027432" href="/articles/384027432">
# <div class="card-photo">
# <img alt="LG 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/a5566f334e3af810b3b2818f0b76725911cbedaf75e755217d468e60a7eb989e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG 제습기</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 강북구 미아동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386340786" href="/articles/386340786">
# <div class="card-photo">
# <img alt="토마토 농장 입니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/82bab9855e741f00994bd55ba5e7df23404f9002e6d114192f7a2f42aa96779b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">토마토 농장 입니다</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경북 상주시 공검면
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 37
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387076548" href="/articles/387076548">
# <div class="card-photo">
# <img alt="다들 너무 비싸게 파시는거 같아서 2000원에 팝니다 5000원으로 파시는거는 좀 아닌거 같아용!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1F7B7E99A973E777C07AC471FEA12243A88F8012603F78E0447279E7DAF036A2.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">다들 너무 비싸게 파시는거 같아서 2000원에 팝니다 5000원으로 파시는거는 좀 아닌거 같아용!</h2>
# <div class="card-price">
#         2,000원
#       </div>
# <div class="card-region-name">
#         전남 광양시 중마동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387329601" href="/articles/387329601">
# <div class="card-photo">
# <img alt="모에스던 쇼파" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/BC6B5E59C7ED3A91CC1BC8BFDE37B50E53BA2B1849DBA8A732F1293A4263C55B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">모에스던 쇼파</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         대구 북구 칠성동
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386370495" href="/articles/386370495">
# <div class="card-photo">
# <img alt="삼성 제습기 만원" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0e697e264a354c73cfd4df58a9fb658ce4a1dc61203e3560b27635b0771ac405.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성 제습기 만원</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         서울 동작구 대방동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387353200" href="/articles/387353200">
# <div class="card-photo">
# <img alt="루이비통 다미에 에바클러치 가방 팔아용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/08D0A3F9D566372D078C265D34B01223851171AD069982F53267659FA05D654E.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">루이비통 다미에 에바클러치 가방 팔아용</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         경기도 수원시 권선구 권선동
#       </div>
# <div class="card-counts">
# <span>
#             관심 13
#           </span>
#         ∙
#         <span>
#             채팅 21
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386621334" href="/articles/386621334">
# <div class="card-photo">
# <img alt="포켓몬빵팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/81d24b2ccf0b3a14092fbd73278044927e4139061f0b1a76384d2c3c61c08321.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵팔아요</h2>
# <div class="card-price blank-price">
#         -
#       </div>
# <div class="card-region-name">
#         전북 익산시 평화동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 50
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387571039" href="/articles/387571039">
# <div class="card-photo">
# <img alt="아우디 푸쉬카팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/6ffbd08b03adb6fe63ba0557532b87b2c58fcdeb018c5bb793d2ed908b3a0ed6.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아우디 푸쉬카팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경북 포항시 남구 효곡동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387329426" href="/articles/387329426">
# <div class="card-photo">
# <img alt="LED 커브드 TV겸 모니터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/116166f3eb366cf62434ce58d526e5454d73bf054bc23132c7cd09c3ccae336f.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LED 커브드 TV겸 모니터</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 향남읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 24
#           </span>
#         ∙
#         <span>
#             채팅 29
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387253711" href="/articles/387253711">
# <div class="card-photo">
# <img alt="다이슨 공기청정기&amp;선풍기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/3b80b1321aa78290191e8bd01c5886b80612d12a73222e973740623f6d0ac6d5.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">다이슨 공기청정기&amp;선풍기</h2>
# <div class="card-price">
#         90,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 고촌읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385962331" href="/articles/385962331">
# <div class="card-photo">
# <img alt="세탁기 무료로 가져 가실분.." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/263adfbfd98671946e58584c86eb17e6aef3ecdbb5ee0f7ccbe6ee03b1d11560.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">세탁기 무료로 가져 가실분..</h2>
# <div class="card-price">
#         10원
#       </div>
# <div class="card-region-name">
#         경북 경산시 하양읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387114344" href="/articles/387114344">
# <div class="card-photo">
# <img alt="뮤츠 띠부띠부씰 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/9a4caecfbbfacfc0e18c6d616aa9ade3a82451c744bcd8001c625c1f3ee20de7.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">뮤츠 띠부띠부씰 팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 만수3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 27
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385907892" href="/articles/385907892">
# <div class="card-photo">
# <img alt="캠핑 가족 모셔요.." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/56fa6c674f0994c756d682e3a2a0791209ee6dabd1a8a8293caa556437abb891.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑 가족 모셔요..</h2>
# <div class="card-price">
#         99원
#       </div>
# <div class="card-region-name">
#         경남 김해시 상동면
#       </div>
# <div class="card-counts">
# <span>
#             관심 116
#           </span>
#         ∙
#         <span>
#             채팅 40
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387039353" href="/articles/387039353">
# <div class="card-photo">
# <img alt="이제쓸일없어서팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/D9264C3ECA7A4CFFFDB5A9D89684DF339BD6B761EF4F97922281C266544415B5.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이제쓸일없어서팝니다</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경기도 파주시 운정3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 31
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387560375" href="/articles/387560375">
# <div class="card-photo">
# <img alt="천왕산가족캠핑장(4/16 토)1박 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/69dec00f8f9aca22dd2ed58336a634a5e9f8802651293ac91864f3ceda1ad682.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">천왕산가족캠핑장(4/16 토)1박 판매합니다</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         서울 구로구 개봉동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386411077" href="/articles/386411077">
# <div class="card-photo">
# <img alt="내친구과학공룡" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/b22c41fad92f3bb2877d69c3223fed276a84284d9b357b4e3f87f9758c74349d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">내친구과학공룡</h2>
# <div class="card-price">
#         130,000원
#       </div>
# <div class="card-region-name">
#         서울 양천구 신정6동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386884515" href="/articles/386884515">
# <div class="card-photo">
# <img alt="포켓몬빵" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/f9a8a15468b6ceb179d2215f9cf8b09a03a6e0d9b28ad066805c9ccef595d7cc.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵</h2>
# <div class="card-price">
#         1,300원
#       </div>
# <div class="card-region-name">
#         경기도 성남시 수정구 양지동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387583007" href="/articles/387583007">
# <div class="card-photo">
# <img alt="LG 휘센 제습기 15리터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0414f9a0b6dadabca3fb19cd0595b3f64f8a5c05f6d4f01e65af5a64758fe1a0.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG 휘센 제습기 15리터</h2>
# <div class="card-price">
#         70,000원
#       </div>
# <div class="card-region-name">
#         부산 연제구 거제제4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385636597" href="/articles/385636597">
# <div class="card-photo">
# <img alt="캐리어 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/DBF39885FDB7FD552EAA4F2F399A62F9BEC51B8A75021E4FA6079A15B0C76EAC.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캐리어 제습기</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 연제구 연산제6동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387435025" href="/articles/387435025">
# <div class="card-photo">
# <img alt="인켈전축" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/f62d583489eeac84b53827dd8336e7f9ca087b071248ee9bbbc6e9eff2fc0fa4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">인켈전축</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경북 포항시 남구 대잠동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386137371" href="/articles/386137371">
# <div class="card-photo">
# <img alt="디월트 드릴 새것 중국내수용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/0b1d34d9a17c076ce19658f17b91ddb90657706594503553327da54e1dbee6a1.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">디월트 드릴 새것 중국내수용</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 금천구 가산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 32
#           </span>
#         ∙
#         <span>
#             채팅 56
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387166559" href="/articles/387166559">
# <div class="card-photo">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ef342419c0e631b246c5cfa820305b95a1b54ddb25b7b95fcc21d62015bc79dd.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         광주 광산구 장덕동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387022503" href="/articles/387022503">
# <div class="card-photo">
# <img alt="캠핑의자 낚시의자 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/7BBD440897B4C7A158927227F7DA8C7CE6462E7042FFD0503CCAA8036146581A.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">캠핑의자 낚시의자 팔아요</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         서울 은평구 불광동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386898565" href="/articles/386898565">
# <div class="card-photo">
# <img alt="접이식 철제 선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/8bd228eea8f3b7c8e47ebd17ff78a769ed67f8afff308e7cd8004a4e91bc3445.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">접이식 철제 선반</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 간석1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387508917" href="/articles/387508917">
# <div class="card-photo">
# <img alt="이케아 선반" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/A8E056A486B25347A918A708FAB0E6841F726A00ECE119746E58D5B6575CF4B6.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">이케아 선반</h2>
# <div class="card-price">
#         6,000원
#       </div>
# <div class="card-region-name">
#         대전 유성구 봉명동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387366157" href="/articles/387366157">
# ...
#         160,000원
#       </div>
# <div class="card-region-name">
#         서울 금천구 가산동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387179584" href="/articles/387179584">
# <div class="card-photo">
# <img alt="삼천리 mtb27단 자전거" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/60ab6a30ce084e10f8c4a683f17f629b323fbe98cca73366f164382b842b237a.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼천리 mtb27단 자전거</h2>
# <div class="card-price">
#         40,000원
#       </div>
# <div class="card-region-name">
#         서울 서대문구 홍은제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384861710" href="/articles/384861710">
# <div class="card-photo">
# <img alt="네스프레소 버츄오 캡슐" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/7E8D37FB2C3D382DA8221BBD8BDE32BA5B412A7BE9DBB25832DF09FA89EF1513.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">네스프레소 버츄오 캡슐</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 해운대구 우동
#       </div>
# <div class="card-counts">
# <span>
#             관심 8
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387004111" href="/articles/387004111">
# <div class="card-photo">
# <img alt="[책장정리]책 팝니다(공룡유치원,이야기솜사탕,한반도와세기의공룡들 외)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/766b505d15e1092ce7555485f40891f5db2a941ace047d8f70dd814702a23576.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">[책장정리]책 팝니다(공룡유치원,이야기솜사탕,한반도와세기의공룡들 외)</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         울산 울주군 범서읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385045307" href="/articles/385045307">
# <div class="card-photo">
# <img alt="18k급처분사정상" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/5c4d16285e02a83cecef7cad975ec0a3fee9846a61cab8af215aeb4f529f3d56.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">18k급처분사정상</h2>
# <div class="card-price">
#         900,000원
#       </div>
# <div class="card-region-name">
#         경북 칠곡군 석적읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387000029" href="/articles/387000029">
# <div class="card-photo">
# <img alt="포켓몬빵 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/671F6588C2FE389090D682E58893ADAD1D3488F665B68B76C486053EC045D6B9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 팝니다</h2>
# <div class="card-price">
#         100원
#       </div>
# <div class="card-region-name">
#         대구 달성군 다사읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 30
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="384897639" href="/articles/384897639">
# <div class="card-photo">
# <img alt="컨테이너 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/25f9a6685479fcd78040a6087012c2067578ee8a00c88321c908dd62b8b16be1.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컨테이너 팝니다</h2>
# <div class="card-price">
#         1,500,000원
#       </div>
# <div class="card-region-name">
#         광주 서구 금호2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 39
#           </span>
#         ∙
#         <span>
#             채팅 43
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386570215" href="/articles/386570215">
# <div class="card-photo">
# <img alt="삼성냉장고 255리터 완전깨끗" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/a0a14d14272a38cc47be0e8d84eae3a1efdc6c8ea521ab670699881dbac71437.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">삼성냉장고 255리터 완전깨끗</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         경기도 고양시 덕양구 향동동
#       </div>
# <div class="card-counts">
# <span>
#             관심 29
#           </span>
#         ∙
#         <span>
#             채팅 26
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385979024" href="/articles/385979024">
# <div class="card-photo">
# <img alt="의자 팝니다(무료)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/83eb2187409d1164826748d756dfa00ce819a0883499c81583351d1276fd5a17.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">의자 팝니다(무료)</h2>
# <div class="card-price">
#         1원
#       </div>
# <div class="card-region-name">
#         충남 논산시 내동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 44
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="385307060" href="/articles/385307060">
# <div class="card-photo">
# <img alt="포켓몬빵 빨리 팔아용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/277BB395134C3D535FA7BA08CD299C865E15606DDDB1E0B703F802FE3772413F.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 빨리 팔아용</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         서울 강북구 번동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 50
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386983173" href="/articles/386983173">
# <div class="card-photo">
# <img alt="아이패드 프로 11인치 3세대(5세대)최신형 판매합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/280a0f6e1428d75bc072a37b218f941e729d0e8ed99eb1eff97b0427a2aad158.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이패드 프로 11인치 3세대(5세대)최신형 판매합니다</h2>
# <div class="card-price">
#         750,000원
#       </div>
# <div class="card-region-name">
#         경기도 김포시 고촌읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 23
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387008952" href="/articles/387008952">
# <div class="card-photo">
# <img alt="마끼다 송풍기, 무선샌딩기 판매합니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/1196c495fcae2658c3fa8c280e857c2cf4b7b9b51ac6943920c4b040f3f813f4.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">마끼다 송풍기, 무선샌딩기 판매합니다.</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         충남 천안시 서북구 두정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387310274" href="/articles/387310274">
# <div class="card-photo">
# <img alt="위닉스 제습기 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/9eee7f2c5c069e2400d232dff9ddfd53936293100b9b6561deeece55e08c419c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 제습기 팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 방배동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386470994" href="/articles/386470994">
# <div class="card-photo">
# <img alt="바테이블, 바의자 판매" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/ca4ae037ffdfb26c9a9cf42454cb0be5cc871e2a1860e9b1d57b103342c09497.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">바테이블, 바의자 판매</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         강원도 동해시 구미동
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="386868741" href="/articles/386868741">
# <div class="card-photo">
# <img alt="쌀 20kg+ 드림" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/F602EB2D08514B63E8A37D8BED5C1104F9AF0914D69D1F20E3E944F3DFB01670.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">쌀 20kg+ 드림</h2>
# <div class="card-price">
#         1,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 논현동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 10
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="387211344" href="/articles/387211344">
# <div class="card-photo">
# <img alt="컴퓨터 부품용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202204/40B01FCD1F0C61B8C44B04B18F03D969544942A247B1CF9CB791292FD309B92C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">컴퓨터 부품용</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         서울 서대문구 연희동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 15
#           </span>
# </div>
# </div>
# </a></article>
# </section>
# <section id="hot-articles-go-download">
# <h3>
#         더 구경하고 싶나요?
#     </h3>
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# <div id="hot-articles-download-buttons">
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a> <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a> </div>
# </section>
# </section>
# <script charset="utf-8" type="text/javascript">
#   function changeRegion(key, value, is_group_article_page){
#     var url_array
#     if(window.location.pathname === "/hot_articles" && window.location.href.match(/\?/)) {
#       url_array = window.location.href.split('?')[1].split(/(?:r1|&?r2)=/)
#       url_array.unshift("")
#     } else {
#       url_array = window.location.pathname.split('/')
#       if(is_group_article_page) {
#           url_array.splice(1,2) // remove 'group_articles/:gid'
#       }
#     }
#     var keys = { r1: 2, r2: 3, r3: 4 }
#     url_array[keys[key]] = value
#     url_array[1] = 'region'
#       if(key == 'r2' && decodeURI(url_array[2]) == "세종특별자치시") {
#         url_array[4] = value
#         url_array[3] = "_"
#       }
#     if(key == 'r1') { url_array.splice(3, 2) }
#     if(key == 'r2' && url_array[3] !== "_") { url_array.splice(4, 1) }
#     if(is_group_article_page) {
#         window.location.href = window.location.origin + window.location.pathname.split('/').slice(0,3).concat(url_array.slice(1)).join('/')
#     } else {
#         window.location.href = window.location.origin + url_array.join('/')
#     }
#   }
# </script>
# <footer id="footer">
# <div class="footer-container">
# <div class="footer-top">
# <div class="footer-logo"></div>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="/trust">믿을 수 있는 중고거래</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="https://cs.kr.karrotmarket.com/wv/faqs">자주 묻는 질문</a></li>
# </ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="https://ads-local.daangn.com" target="_blank">광고주센터</a></li>
# <li class="footer-list-item">
# <a href="https://daangnpay.com" target="_blank">당근페이</a>
# <li class="footer-list-item">
# <a class="ga-click" data-event-action="hot_articles" data-event-category="town_link_from" data-event-label="footer_town" href="https://town.daangn.com" target="_blank">동네가게</a>
# </li>
# </li></ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a href="https://team.daangn.com/" target="_blank">회사 소개</a></li>
# <li class="footer-list-item"><a href="https://team.daangn.com/jobs/" target="_blank">채용</a></li>
# </ul>
# <ul class="footer-list policy">
# <li class="footer-list-item"><a href="https://policy.daangn.com/terms.html" target="_blank">이용약관</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/privacy.html" target="_blank">개인정보처리방침</a></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/location.html" target="_blank">위치기반서비스 이용약관</a></li>
# </ul>
# </div>
# <div class="footer-bottom">
# <div id="copyright">
# <ul class="copyright-list">
# <li class="copyright-list-item">고객문의 <a href="mailto:cs@daangnservice.com">cs@daangnservice.com</a></li>
# <li class="copyright-list-item">제휴문의 <a href="mailto:contact@daangn.com">contact@daangn.com</a></li>
# </ul>
# <ul class="copyright-list">
# <li class="copyright-list-item">지역광고 <a href="mailto:ad@daangn.com">ad@daangn.com</a></li>
# <li class="copyright-list-item">PR문의 <a href="mailto:pr@daangn.com">pr@daangn.com</a></li>
# </ul>
# <ul class="copyright-list copyright-list-light">
# <li class="copyright-list-item"><address>서울특별시 구로구 디지털로30길 28, 609호 (당근서비스)</address></li>
# <li class="copyright-list-item">사업자 등록번호 : 375-87-00088</li>
# <li class="copyright-list-item">직업정보제공사업 신고번호 : J1200020200016</li>
# </ul>
# <div id="social">
# <ul class="social-list">
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.facebook.com/daangn" target="_blank">
# <img alt="facebook" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-facebook-0563f4a93852d073b41f13b8bcabb03d47af3bb3a6755cdfedd8a73686c7f18c.svg"/>
# <span class="sr-only">facebook</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.instagram.com/daangnmarket/" target="_blank">
# <img alt="instagram" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-instagram-2f6c88a461597907c114b7ce28eab053fcae791ed26417915fefb6f7c9f95756.svg"/>
# <span class="sr-only">instagram</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://blog.naver.com/daangn" target="_blank">
# <img alt="blog" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-blog-e1b0d512d1766a6962ec5bbb5b0803d2a6a9c55ad97db5ba9eebb76013caceba.svg"/>
# <span class="sr-only">blog</span>
# </a> </li>
# <li class="global-links">
# <img alt="country" height="24" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-global-2f53678b428ec623cefd07a90dd7777f3e55fc0433918f645d7d75ace6ff1fc3.png" width="24"/>
# <select id="global-links-select">
# <option value="kr">한국</option>
# <option value="https://uk.karrotmarket.com">영국</option>
# <option value="https://ca.karrotmarket.com">캐나다</option>
# <option value="https://us.karrotmarket.com">미국</option>
# <option value="https://jp.karrotmarket.com">일본</option>
# </select>
# </li>
# </ul>
# </div>
# <div class="copyright-text">©Danggeun Market Inc.</div>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %%
print('class 속성을 활용해서 card-title 만 가져온다면 - ') 
print()

# soup.findAll(class_ = 'card-title')
# card = soup.find_all(class_='card-title')
# card_titles = soup.findAll(class_ = 'card-title')


for title in soup.find_all('h2' , attrs = {'class' : 'card-title'}) :
    print(title.string)
# Out:
# class 속성을 활용해서 card-title 만 가져온다면 -
#
# 디월트 20v  5ah배터리
# 카페 정리합니다
# 선반
# 포켓몬 빵 팔아요.
# 자전거판매해요 / 엘파마(ELFAMA)로사 R370 MTB(입문용모델).
# 위닉스뽀송 제습기
# 포켓몬빵 사실분
# ⭐포.켓.몬.빵⭐포켓몬 ! 띠부띠부 !
# 50인치TV 싸게 팔아요!! 급처!!
# 제습기 가져가실분
# 4단 서랍장 이사로 급매합니다.
# 이케아 나무선반
# 창고정리♥디월트 드릴 만원
# 라탄의자 판매
# 농업용3톤 물탱크 판매합니다
# 삼성냉동고
# 버버리 미니 크로스백
# 냉장고
# 전자기타 팝니다
# 아세아관리기
# Tv
# 포켓몬 빵 팝니다.
# 에어컨
# LG통돌이 세탁기, 캔디 건조기 판매합니다
# 좋은책어린이 저학년문고
# 에어컨 철거해 가실 분
# 영암꿀고구마(한입)
# 갤럭시노트10 256G
# 자전거 판매합니다.
# 아이폰12프로 그레파이트 128g 배터리성능👍
# 무료드림 전자렌지
# 파라솔
# 5단선반
# 포켓몬빵 팝니다
# 포르쉐 푸쉬카
# 내친구 과학공룡 전집 53권
# 구글 크롬캐스트4
# 투인원 휘센 에어컨, LG세탁기 팔아요
# 스테인레스제 칼세트
# 포켓몬빵 팝니다
# 산드로 가디건
# 접이식 자전거 팝니다
# 스팸 좋아하시는분!
# 포켓몬빵 ‘정가’ 판매합니다
# LG 제습기
# 토마토 농장 입니다
# 다들 너무 비싸게 파시는거 같아서 2000원에 팝니다 5000원으로 파시는거는 좀 아닌거 같아용!
# 모에스던 쇼파
# 삼성 제습기 만원
# 루이비통 다미에 에바클러치 가방 팔아용
# 포켓몬빵팔아요
# 아우디 푸쉬카팔아요
# LED 커브드 TV겸 모니터
# 다이슨 공기청정기&선풍기
# 세탁기 무료로 가져 가실분..
# 뮤츠 띠부띠부씰 팔아요
# 캠핑 가족 모셔요..
# 이제쓸일없어서팝니다
# 천왕산가족캠핑장(4/16 토)1박 판매합니다
# 내친구과학공룡
# 포켓몬빵
# LG 휘센 제습기 15리터
# 캐리어 제습기
# 인켈전축
# 디월트 드릴 새것 중국내수용
# 제습기
# 캠핑의자 낚시의자 팔아요
# 접이식 철제 선반
# 이케아 선반
# 이사할때 쓰는
# 1년사용한 에어컨 팝니다
# 냉장고
# 포켓몬 빵  비싸게팔아요
# 자이크 여성 자전거
# 선반
# 자전거
# 가정용 미싱 내놔요.
# LG 32인치 티비팔아요
# 30m 캠핑 릴선 판매
# 로드 자전거
# pxg 골프웨어
# 코렐 냄비 세트
# lg 인버터 에어컨 (냉난방)
# 신세계상품권 18만원 -> 16만원에 급처
# 삼천리 mtb27단 자전거
# 네스프레소 버츄오 캡슐
# [책장정리]책 팝니다(공룡유치원,이야기솜사탕,한반도와세기의공룡들 외)
# 18k급처분사정상
# 포켓몬빵 팝니다
# 컨테이너 팝니다
# 삼성냉장고 255리터 완전깨끗
# 의자 팝니다(무료)
# 포켓몬빵 빨리 팔아용
# 아이패드 프로 11인치 3세대(5세대)최신형 판매합니다
# 마끼다 송풍기, 무선샌딩기 판매합니다.
# 위닉스 제습기 팔아요
# 바테이블, 바의자 판매
# 쌀 20kg+ 드림
# 컴퓨터 부품용

# %% [markdown]
# - css 선택자를 이용한 태그탐색( select() )
# - id : #
# - class : .
# - 자손(html > title) 직계 , 하위(html title) 직계가 아니여도 선택자 사용가능

# %%
print( 'type - ' , type( soup.select('.card-title') ))
print()
print( soup.select('.card-title') )
# Out:
# type -  <class 'bs4.element.ResultSet'>
#
# [<h2 class="card-title">디월트 20v  5ah배터리</h2>, <h2 class="card-title">카페 정리합니다</h2>, <h2 class="card-title">선반</h2>, <h2 class="card-title">포켓몬 빵 팔아요.</h2>, <h2 class="card-title">자전거판매해요 / 엘파마(ELFAMA)로사 R370 MTB(입문용모델).</h2>, <h2 class="card-title">위닉스뽀송 제습기</h2>, <h2 class="card-title">포켓몬빵 사실분</h2>, <h2 class="card-title">⭐포.켓.몬.빵⭐포켓몬 ! 띠부띠부 !</h2>, <h2 class="card-title">50인치TV 싸게 팔아요!! 급처!!</h2>, <h2 class="card-title">제습기 가져가실분</h2>, <h2 class="card-title">4단 서랍장 이사로 급매합니다.</h2>, <h2 class="card-title">이케아 나무선반</h2>, <h2 class="card-title">창고정리♥디월트 드릴 만원</h2>, <h2 class="card-title">라탄의자 판매</h2>, <h2 class="card-title">농업용3톤 물탱크 판매합니다</h2>, <h2 class="card-title">삼성냉동고</h2>, <h2 class="card-title">버버리 미니 크로스백</h2>, <h2 class="card-title">냉장고</h2>, <h2 class="card-title">전자기타 팝니다</h2>, <h2 class="card-title">아세아관리기</h2>, <h2 class="card-title">Tv</h2>, <h2 class="card-title">포켓몬 빵 팝니다.</h2>, <h2 class="card-title">에어컨</h2>, <h2 class="card-title">LG통돌이 세탁기, 캔디 건조기 판매합니다</h2>, <h2 class="card-title">좋은책어린이 저학년문고</h2>, <h2 class="card-title">에어컨 철거해 가실 분</h2>, <h2 class="card-title">영암꿀고구마(한입)</h2>, <h2 class="card-title">갤럭시노트10 256G</h2>, <h2 class="card-title">자전거 판매합니다.</h2>, <h2 class="card-title">아이폰12프로 그레파이트 128g 배터리성능👍</h2>, <h2 class="card-title">무료드림 전자렌지</h2>, <h2 class="card-title">파라솔</h2>, <h2 class="card-title">5단선반</h2>, <h2 class="card-title">포켓몬빵 팝니다</h2>, <h2 class="card-title">포르쉐 푸쉬카</h2>, <h2 class="card-title">내친구 과학공룡 전집 53권</h2>, <h2 class="card-title">구글 크롬캐스트4</h2>, <h2 class="card-title">투인원 휘센 에어컨, LG세탁기 팔아요</h2>, <h2 class="card-title">스테인레스제 칼세트</h2>, <h2 class="card-title">포켓몬빵 팝니다</h2>, <h2 class="card-title">산드로 가디건</h2>, <h2 class="card-title">접이식 자전거 팝니다</h2>, <h2 class="card-title">스팸 좋아하시는분!</h2>, <h2 class="card-title">포켓몬빵 ‘정가’ 판매합니다</h2>, <h2 class="card-title">LG 제습기</h2>, <h2 class="card-title">토마토 농장 입니다</h2>, <h2 class="card-title">다들 너무 비싸게 파시는거 같아서 2000원에 팝니다 5000원으로 파시는거는 좀 아닌거 같아용!</h2>, <h2 class="card-title">모에스던 쇼파</h2>, <h2 class="card-title">삼성 제습기 만원</h2>, <h2 class="card-title">루이비통 다미에 에바클러치 가방 팔아용</h2>, <h2 class="card-title">포켓몬빵팔아요</h2>, <h2 class="card-title">아우디 푸쉬카팔아요</h2>, <h2 class="card-title">LED 커브드 TV겸 모니터</h2>, <h2 class="card-title">다이슨 공기청정기&amp;선풍기</h2>, <h2 class="card-title">세탁기 무료로 가져 가실분..</h2>, <h2 class="card-title">뮤츠 띠부띠부씰 팔아요</h2>, <h2 class="card-title">캠핑 가족 모셔요..</h2>, <h2 class="card-title">이제쓸일없어서팝니다</h2>, <h2 class="card-title">천왕산가족캠핑장(4/16 토)1박 판매합니다</h2>, <h2 class="card-title">내친구과학공룡</h2>, <h2 class="card-title">포켓몬빵</h2>, <h2 class="card-title">LG 휘센 제습기 15리터</h2>, <h2 class="card-title">캐리어 제습기</h2>, <h2 class="card-title">인켈전축</h2>, <h2 class="card-title">디월트 드릴 새것 중국내수용</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">캠핑의자 낚시의자 팔아요</h2>, <h2 class="card-title">접이식 철제 선반</h2>, <h2 class="card-title">이케아 선반</h2>, <h2 class="card-title">이사할때 쓰는</h2>, <h2 class="card-title">1년사용한 에어컨 팝니다</h2>, <h2 class="card-title">냉장고</h2>, <h2 class="card-title">포켓몬 빵  비싸게팔아요</h2>, <h2 class="card-title">자이크 여성 자전거</h2>, <h2 class="card-title">선반</h2>, <h2 class="card-title">자전거</h2>, <h2 class="card-title">가정용 미싱 내놔요.</h2>, <h2 class="card-title">LG 32인치 티비팔아요</h2>, <h2 class="card-title">30m 캠핑 릴선 판매</h2>, <h2 class="card-title">로드 자전거</h2>, <h2 class="card-title">pxg 골프웨어</h2>, <h2 class="card-title">코렐 냄비 세트</h2>, <h2 class="card-title">lg 인버터 에어컨 (냉난방)</h2>, <h2 class="card-title">신세계상품권 18만원 -&gt; 16만원에 급처</h2>, <h2 class="card-title">삼천리 mtb27단 자전거</h2>, <h2 class="card-title">네스프레소 버츄오 캡슐</h2>, <h2 class="card-title">[책장정리]책 팝니다(공룡유치원,이야기솜사탕,한반도와세기의공룡들 외)</h2>, <h2 class="card-title">18k급처분사정상</h2>, <h2 class="card-title">포켓몬빵 팝니다</h2>, <h2 class="card-title">컨테이너 팝니다</h2>, <h2 class="card-title">삼성냉장고 255리터 완전깨끗</h2>, <h2 class="card-title">의자 팝니다(무료)</h2>, <h2 class="card-title">포켓몬빵 빨리 팔아용</h2>, <h2 class="card-title">아이패드 프로 11인치 3세대(5세대)최신형 판매합니다</h2>, <h2 class="card-title">마끼다 송풍기, 무선샌딩기 판매합니다.</h2>, <h2 class="card-ti ...

# %%
print( soup.select('#hot-articles-go-download > div > a' ) )
print()
for a in soup.select('#hot-articles-go-download > div > a' ) : 
    print(a)
    print()
# Out:
# [<a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a>, <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a>]
#
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a>
#
# <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a>

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

try :
    html = urlopen('http://www.pythonscraping.com/pages/page3.html')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    # print(html.read())
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
# type( soup.select('#giftList') )
print('type - ' , type( soup.find('table' , attrs = {'id' : 'giftList'}) ) )
print()
table = soup.find('table' , attrs = {'id' : 'giftList'})
# Out:
# type -  <class 'bs4.element.Tag'>

# %%
print('title, desc, cost, img 데이터 추출 후')
print('데이터 프레임으로 만들어 본다면? - ')
print()

title_lst = []
desc_lst  = []
cost_lst  = []
img_lst   = []

datas = []
for trs in table.find_all('tr') :
    
    # print(tr)
    # print('*' * 50)
    # print( trs.find_all('td'))
    
    tds = trs.find_all('td')
    
    for td in tds :
        if td.find('img') :
            title_lst.append( tds[0].get_text().strip() )
            
            desc_lst.append(  tds[1].get_text().strip() )
            
            cost_lst.append(  tds[2].get_text().strip() )
            
            img_lst.append(   tds[3].find('img')['src'] ) 
            
#             print( tds[0].get_text().strip() )
#             print( tds[1].get_text().strip() )
#             print( tds[2].get_text().strip() )
#             print( tds[3].find('img')['src'] )
#             print("*" * 50)
                
#             datas.append([tds[0].get_text().strip() , tds[1].get_text().strip() , tds[2].get_text().strip() , tds[3].find('img')['src']])
# Out:
# title, desc, cost, img 데이터 추출 후
# 데이터 프레임으로 만들어 본다면? -

# %%
scraping_frm = pd.DataFrame({
    'title' : title_lst , 
    'desc'  : desc_lst , 
    'cost'  : cost_lst , 
    'img'   : img_lst 
})
scraping_frm
# Out:
#                    title                                               desc  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#          cost                    img
# 0      $15.00  ../img/gifts/img1.jpg
# 1  $10,000.52  ../img/gifts/img2.jpg
# 2  $10,005.00  ../img/gifts/img3.jpg
# 3       $0.50  ../img/gifts/img4.jpg
# 4       $1.50  ../img/gifts/img6.jpg

# %%
scraping_frm.to_csv('./scraping-data/scraping_frm.csv' , encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7416/1364674894.py in <module>
# ----> 1 scraping_frm.to_csv('./scraping-data/scraping_frm.csv' , encoding = 'utf-8')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './scraping-data/scraping_frm.csv'

# %% [markdown]
# - https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.YT618p0zaUn

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

try :
    html = urlopen('https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.YT618p0zaUn')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    # print(html.read())
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
print(' css 선택자 - ')
sevenDays = soup.select('#seven-day-forecast')
# print( type( sevenDays ) )
print(' 태그 탐색  - ')
sevenDays = soup.find('div' , attrs = {'id' : 'seven-day-forecast' })
print( sevenDays )

# %%
forecast = sevenDays.find_all('div' , attrs = {'class' : 'tombstone-container'})
forecast

# %%
print('period-name, desc , src , temp 프레임 만들기')
print('조건) select() 함수 이용 ')

# %%
periods = soup.select('.tombstone-container > .period-name')
periods = [ tag.get_text() for tag in periods]
periods

# %%
descs = soup.select('.tombstone-container > .short-desc')
descs = [ tag.get_text() for tag in descs]
descs

# %%
imgs = soup.select('.tombstone-container  .forecast-icon')
imgs = [ tag['src'] for tag in imgs]
imgs

# %%
temps = soup.select('.tombstone-container  .temp')
temps = [ tag.get_text() for tag in temps]
temps

# %%
print('len() - ' , len(periods) , len(descs) , len(imgs) , len(temps))

# %%
forecast_frm = pd.DataFrame({
    'periods' : periods , 
    'descs'  : descs , 
    'imgs'  : imgs , 
    'temps'   : temps 
})
forecast_frm

# %% [markdown]
# - https://pythondojang.bitbucket.io/weather/observation/currentweather.html

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

try :
    html = urlopen('https://pythondojang.bitbucket.io/weather/observation/currentweather.html')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    # print(html.read())
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
print('location, temp, humidity 데이터 추출 후')
print('데이터 프레임으로 만들어 본다면? - ')

loc_lst = []
temp_lst = []
humidity_lst = []

datas = []

table = soup.find('table', class_ = 'table_develop3')
table


for tr in table.find_all('tr') :
    
    tds = tr.find_all('td')

    for td in tds :
        if td.find('a') :
            loc_lst.append(tds[0].a.get_text())
            temp_lst.append(tds[5].get_text().strip() )
            humidity_lst.append(tds[9].get_text().strip() )

weather_frm = pd.DataFrame({
    'location' : loc_lst,
    'temp' : temp_lst,
    'humidity' :humidity_lst
})
weather_frm

# %% [markdown]
# - https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx
# - 선수명 , avg , hit , homerun , rbi
# - avg 상위 5 명의 선수에 대한 bar 시각화 구현 [실습]
